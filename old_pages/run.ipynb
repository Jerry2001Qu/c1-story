# %%
from pathlib import Path
import os
import random

from src.dataloader import LocalDataLoader
from src.clip_manager import ClipManager
from src.news_script import NewsScript
from src.video_editor import VideoEditor
from src.error_handler import StdOutErrorHandler 
from src.audio_processor import AudioProcessor
from src.gcp import GCSManager

# %%
anchor_idx = 2
live_anchor = True
test_mode = False

anchor_map = [
    ("yELTnbNFhESclGsoYVTM", "l6Qo5Atx1JTwyCLkMKQm", "6afc5b115c6f440aa92f43a32f50616f", "assets/EDDIE-square.png"),
    ("9f8o652aaiVK5HavyCf1", "l6Qo5Atx1JTwyCLkMKQm", "20251eb0e4504ddbb913f1b09e2bbb8e", "assets/DANIEL-square.png"),
    ("dyhDlCWGL3pDsrANTLru", "l6Qo5Atx1JTwyCLkMKQm", "395e53f63eba4ce9a9e3dddc9a0263ed", "assets/MIRANDA-square.png"),
    # ("H2LXjnBS1droRODepT50", "l6Qo5Atx1JTwyCLkMKQm", "e1dfdd60549940159aa4eb529e6f78a7", "assets/SARAH-square.png"),
    ("GxOlMeAhhAqPmZNfxxUm", "l6Qo5Atx1JTwyCLkMKQm", "2c67e653633c4894834585e3a9d5b2be", "assets/KARA-square.png"),
]
anchor_voice_id, voiceover_voice_id, anchor_avatar_id, anchor_image_path = anchor_map[anchor_idx]

music = False
high_res = True
output_resolution = (1280, 720) if high_res else (640, 360)
bitrate = "3M" if high_res else "1M"

error_handler = StdOutErrorHandler()

story_folder = Path("assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms")
dataloader = LocalDataLoader(story_folder)
storyline = dataloader.load_storyline()
shotlist = dataloader.load_shotlist()
story_title = dataloader.get_story_title()
video_file_path = dataloader.get_video_file_path()

# %%
clips_folder = story_folder / "clips"
clip_manager = ClipManager(video_file_path, clips_folder, shotlist, anchor_image_path, anchor_voice_id, voiceover_voice_id, anchor_avatar_id, has_splash_screen=False, error_handler=error_handler)
script = NewsScript(storyline, shotlist, clip_manager, dataloader, folder=story_folder, error_handler=error_handler)
print("Splitting video into clips")
clip_manager.split_video_into_clips()
print("Loading clips")
clip_manager.load_clips()
print("Transcribing clips")
clip_manager.transcribe_clips(multi=True)
print("Matching clips")
clip_manager.match_clips()
print("Breaking up clips")
clip_manager.break_up_clips()
print("Generating full descriptions")
clip_manager.generate_full_descriptions(story_title)
# Out:
# Splitting video into clips
# INFO: Detected 60 clips
# Loading clips
# Transcribing clips
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/003.mp3
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/001.mp3
# chunk:   2%|██                                                                                                             | 1/53 [00:00<00:00, 642.71it/s, now=None]
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/002.mp3
# chunk:   0%|                                                                                                                      | 0/2259 [00:00<?, ?it/s, now=None]
#
#
#
#
#
#
# chunk:   7%|███████▊                                                                                                  | 115/1556 [00:00<00:00, 2691.39it/s, now=None]
# chunk:   5%|█████▍                                                                                                    | 115/2259 [00:00<00:00, 2463.33it/s, now=None]
# chunk:  10%|███████████                                                                                               | 236/2259 [00:00<00:00, 2358.73it/s, now=None]
#
# chunk:  16%|█████████████████                                                                                         | 250/1556 [00:00<00:00, 2499.95it/s, now=None]
# MoviePy - Done.
# chunk:  22%|███████████████████████▏                                                                                  | 494/2259 [00:00<00:00, 2475.96it/s, now=None]
#
# chunk:  37%|███████████████████████████████████████                                                                   | 574/1556 [00:00<00:00, 2932.89it/s, now=None]
# chunk:  37%|███████████████████████████████████████▌                                                                  | 842/2259 [00:00<00:00, 2895.75it/s, now=None]
#
# chunk:  61%|████████████████████████████████████████████████████████████████▋                                         | 950/1556 [00:00<00:00, 3289.33it/s, now=None]
# chunk:  51%|█████████████████████████████████████████████████████▋                                                   | 1156/2259 [00:00<00:00, 2987.11it/s, now=None]
#
# chunk:  84%|████████████████████████████████████████████████████████████████████████████████████████▋                | 1314/1556 [00:00<00:00, 3424.00it/s, now=None]
#
#
#
# chunk:  64%|██████████████████████████████████████████████████████████████████▊                                      | 1437/2259 [00:00<00:00, 2987.11it/s, now=None]
# chunk:  65%|████████████████████████████████████████████████████████████████████▌                                    | 1474/2259 [00:00<00:00, 3053.77it/s, now=None]
# chunk:  79%|██████████████████████████████████████████████████████████████████████████████████▊                      | 1782/2259 [00:00<00:00, 3060.23it/s, now=None]
# MoviePy - Done.
# chunk:  95%|███████████████████████████████████████████████████████████████████████████████████████████████████▍     | 2138/2259 [00:00<00:00, 3218.52it/s, now=None]
# MoviePy - Done.
# ## Identified Speech (002)
# Folks, with your permission, I'm gonna find out whether you have any ice cream. You know, ain't it really dull when you have a president who's known for 2 things, Ray Bans sunglasses and choco chip ice cream?
# ## Identified Speech (001)
# My name is Felicia Spriggs Wilkerson. I am the president of AFSCME's Local 3130. Folks, I make no apologies for being the post pro union president of American history. No. I mean it. You know, after we anyway, you know, I've you heard me say it before, but I'll say it again and again and again. The middle class built this country, not Wall Street. And guess what? Unions built the middle class. And I know how to say unions. It's made how a lot of people talk about labor. Unions. Unions. 1 of the things we're gonna change in the second term is we're gonna have a fairer tax system. We got a little fair. We made those 55 companies who didn't pay a penny in taxes and made $40, 000, 000, 000. We made them pay, but it's only 23%. So they're not paying 15%. They're not paying enough. You got out there literally, you got a 1000 billionaires in America, up to a 1000 billionaires. You know what their average tax rate is? 8.3%. Well, no. What what here's the point I wanna make, Joe. This is very serious. I'm not joking about this 1. The fact of the matter is Trump wants to give another, and he's decided, a 5 $1, 000, 000, 000, 000 tax cut over the next 5 years. No. I'm I'm not joking. You know what we're gonna do? We're gonna stop it. We're gonna spend that money on childcare. We're sending that money no. I'm I mean it. We're sending that money on elder care.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/004.mp3
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/005.mp3
# MoviePy - Done.
# 2024-07-09 00:23:16.283 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/006.mp3
# MoviePy - Done.
# ## Identified Speech (006)
# It's not fair.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/007.mp3
# MoviePy - Done.
# ## Identified Speech (007)
# Your excellencies, for the family photo, we would invite you to look in the central camera for 8.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/008.mp3
# chunk:   8%|████████▎                                                                                                 | 126/1595 [00:00<00:00, 1987.10it/s, now=None]
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/009.mp3
#
# chunk:   9%|█████████▎                                                                                                | 140/1595 [00:00<00:00, 1653.70it/s, now=None]
# chunk:   9%|█████████▌                                                                                                | 143/1595 [00:00<00:01, 1421.36it/s, now=None]
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/010.mp3
# chunk:   0%|                                                                                                                       | 0/163 [00:00<?, ?it/s, now=None]
#
#
# chunk:  28%|█████████████████████████████▍                                                                            | 443/1595 [00:00<00:00, 1421.36it/s, now=None]
# MoviePy - Done.
# chunk:  33%|███████████████████████████████████                                                                       | 528/1595 [00:00<00:00, 2845.62it/s, now=None]
# MoviePy - Done.
# MoviePy - Done.
# ## Identified Speech (010)
# To the west, than it is to Russia. And so, I, I I'm hopeful that
# ## Identified Speech (009)
# Woah. Woah. Woah. Woah. Woah. Woah. Woah. Woah. No. Yeah. 1 final question.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/011.mp3
# chunk:  13%|█████████████▌                                                                                             | 117/922 [00:00<00:00, 1991.93it/s, now=None]
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/012.mp3
# chunk:  27%|█████████████████████████████▏                                                                             | 252/922 [00:00<00:00, 2500.95it/s, now=None]
# chunk:  54%|█████████████████████████████████████████████████████████▍                                                 | 495/922 [00:00<00:00, 2500.95it/s, now=None]
# MoviePy - Done.
# MoviePy - Done.
# ## Identified Speech (008)
# It is important for the American electorate to know whether Biden is in good shape. And what we saw at the debate was a aberration of 1 of, or whether there is a more systematic decline. And that kind of more systematic decline would probably be apparent over a course of a 7 day summit of this sort. Will foreign leaders be making their own assessments about this? I'm I'm sure they have to simply because it's too much a part of the political conversation and part of their, their, own effort to judge where things stand. Are they going to say anything about this, or will they be public about it? Absolutely not. This is going to be a summit that focuses on the diplomacy, on support for Ukraine. No leader is going to run the risk of intervening in American politics by offering some port some sort of public judgment about president Biden's cognitive capabilities.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/013.mp3
# MoviePy - Done.
# ## Identified Speech (011)
# I think the the summit agenda, the conversations will be unaffected by the continuing discussions about president Biden's debate performance and whether he should stay in the race. NATO summits are fairly scripted affairs. The deliverables are worked out well in advance. And in many respects, this is a a diplomatic meeting that will focus on supporting Ukraine. And behind the scenes, there's a great deal of anxiety about the US election and who's going to come out on top. There's a great deal of anxiety about similar political developments in Europe.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/014.mp3
# MoviePy - Done.
# ## Identified Speech (014)
# I think 1 of the strong suits of president Biden when it comes to a contest with Donald Trump is his popularity on the global stage, the degree to which he's rebuilt alliances, the successful effort to prevent Russia from subjugating Ukraine. And the president had a series of events at d day, a big meeting in Paris, a meeting at the g 7 in which he showcased his his leadership, of NATO and of of the west. And that will that will be on show during the NATO summit. And it is an opportunity for the president to try to alleviate some of the doubts that emerged from his debate performance.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/015.mp3
# MoviePy - Done.
# ## Identified Speech (013)
# Thank you very much.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/016.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/017.mp3
# ## Identified Speech (015)
# You don't have a problem in Russia. We have. You don't have a problem.
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/018.mp3
# MoviePy - Done.
# ## Identified Speech (017)
# Hello, everybody.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/019.mp3
# chunk:  26%|███████████████████████████▏                                                                              | 304/1184 [00:00<00:00, 3005.17it/s, now=None]
# ## Identified Speech (018)
# 1 of the presidents of a big country stood up, said, well, sir, if we don't pay and we're attacked by Russia, will you protect us? I said, you didn't pay? You're delinquent? He said, yes. Let's say that happened. No. I would not protect you. In fact, I would encourage them to do whatever the hell they want. You gotta pay. You gotta pay your bills.
# chunk:  82%|██████████████████████████████████████████████████████████████████████████████████████▍                   | 966/1184 [00:00<00:00, 3181.02it/s, now=None]
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/020.mp3
# MoviePy - Done.
# ## Identified Speech (019)
# I think that right across the the alliance, right across NATO members, including Ukraine, there is hope, if not prayer, for a second Biden term because Biden did reinvigorate the Atlantic alliance. Biden has led the effort to support Ukraine. And in contrast, Trump turned his back on the allies during his first term in office. He mused about withdrawing from NATO. He has said during, this election campaign, if there are NATO members who don't spend enough on defense, I'm gonna tell the Russians to have their way with them. And there is concern that the United States could withdraw from NATO if president, Trump is returned to office.
# ## Identified Speech (020)
# You
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/021.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/022.mp3
# MoviePy - Done.
# ## Identified Speech (021)
# You
# ## Identified Speech (022)
# ♪♪
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/023_0.mp3
# chunk:   2%|█▊                                                                                                           | 2/122 [00:00<00:00, 1378.35it/s, now=None]
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/023_1.mp3
# MoviePy - Done.
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/023_2.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/024.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/025.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/026.mp3
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/027_0.mp3
# MoviePy - Done.
# MoviePy - Done.
# ## Identified Speech (026)
#
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/027_1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/028.mp3
# MoviePy - Done.
# ## Identified Speech (028)
# Ukraine will will dominate the conversation, as it should. There is a major war going on. The Ukrainians suffered through a delay in the arrival of American aid about 7 months while congress debated what turned out to be a 61, 000, 000, 000 package. The armaments that are bought with that money have been arriving. They are getting to the front, and that is enabling Ukraine to hold the line.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/029.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/030.mp3
# MoviePy - Done.
# ## Identified Speech (029)
#
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/031.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/032.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/033.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/034_0.mp3
# chunk:  11%|████████████▎                                                                                                | 11/97 [00:00<00:00, 5634.75it/s, now=None]
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/034_1.mp3
# MoviePy - Done.
# MoviePy - Done.
# ## Identified Speech (033)
# Well, I I do think that there will be a a conversation about NATO's ability to protect NATO members. Right? We've got 2 new members of NATO, Sweden and Finland. Finland has a very long land border with Russia that requires NATO to update its operational plans for the defense of, NATO territory, including Finland and Estonia and other countries that either border Russia, border Belarus, which is an ally of Russia. So there's there there are just nitty gritty things that will get discussed at this summit. China will surely be on the agenda, because there, there is concern about Chinese support for Russia during its war against Ukraine. There is concern about what steps NATO collectively needs to take economically as well as strategically to deal with the China threat.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/035.mp3
# MoviePy - Done.
# ## Identified Speech (034_1)
# Thank you. Thank you. Thank you. Thank you.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/036_0.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/036_1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/037_0.mp3
# MoviePy - Done.
# ## Identified Speech (037_0)
# you
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/037_1.mp3
# MoviePy - Done.
# ## Identified Speech (036_0)
# you
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/038_0.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/038_1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/039_0.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/039_1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/040_0.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/040_1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/041_0.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/041_1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/042_0.mp3
# chunk:   7%|████████                                                                                                    | 11/148 [00:00<00:00, 3531.37it/s, now=None]
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/042_1.mp3
# MoviePy - Done.
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/042_2.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/043_0.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/043_1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/044_0.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/044_1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/045_0.mp3
# MoviePy - Done.
# ## Identified Speech (044_0)
# you
# MoviePy - Writing audio in assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/clips/045_1.mp3
# MoviePy - Done.
# 2024-07-09 00:26:34.681 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# ## None
# Transcription complete. Successful: 60, Failed: 0
# Matching clips
# 2024-07-09 00:27:12.695 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-07-09 00:27:22.516 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# ## None
# 001: 5
# 002: 7
# 003: None
# 004: None
# 005: None
# 006: None
# 007: None
# 008: 13
# 009: None
# 010: None
# 011: 16
# 012: None
# 013: None
# 014: 19
# 015: None
# 016: None
# 017: None
# 018: 23
# 019: 24
# 020: None
# 021: None
# 022: None
# 023_0: None
# 023_1: None
# 023_2: None
# 024: None
# 025: None
# 026: None
# 027_0: None
# 027_1: None
# 028: 32
# 029: None
# 030: None
# 031: None
# 032: None
# 033: 36
# 034_0: None
# 034_1: None
# 035: None
# 036_0: None
# 036_1: None
# 037_0: None
# 037_1: None
# 038_0: None
# 038_1: None
# 039_0: None
# 039_1: None
# 040_0: None
# 040_1: None
# 041_0: None
# 041_1: None
# 042_0: None
# 042_1: None
# 042_2: None
# 043_0: None
# 043_1: None
# 044_0: None
# 044_1: None
# 045_0: None
# 045_1: None
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# 2024-07-09 00:30:29.864
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/jerry/code/c1-story/venv/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# Breaking up clips
# INFO: Split 60 clips into 60 clips
# Generating full descriptions
# ## Analyzing clip 005
# ## Video Description:
#
# **Shot:** Wide, static, professional. The framing suggests this is captured from a designated press area at an official event.
#
# **Location:** A stage with a blue backdrop featuring a subtle design (too blurry to discern). The presence of numerous flags suggests an international gathering.
#
# **Time:**  Daytime, judging by the lighting and attire.
#
# **0:00-0:08**
#
# The camera focuses on a line of individuals, predominantly men in suits, standing shoulder-to-shoulder. They are smiling and engaging in light conversation, suggesting a relaxed atmosphere despite the formality of the occasion.
#
# **People:**  While the video focuses on the backs of most individuals, President Biden is briefly visible (0:04-0:06) as he shakes hands with someone outside the frame. The presence of other individuals who appear to be dignitaries points towards this being a high-level meeting.
#
# **Comments:**
#
# * The video captures a behind-the-scenes moment of camaraderie amongst world leaders.
# * The formal attire and setting contrast with the relaxed demeanor of the individuals, offering a glimpse into the human element of international diplomacy.
# * Identifying other individuals present could provide valuable context for the event.
#
# **Minimum Timing:** 2-3 seconds. While the shot is relatively static, a brief duration is sufficient to convey the atmosphere and identify key individuals.
#
# **Rating:** 6/10. This clip provides a glimpse into the atmosphere of a high-level meeting and features President Biden. However, without further context about the event and participants, its news value is limited.
#
# ## Analyzing clip 003
# ## Video Description:
#
# **Shot:** Medium-distance, static shot, likely captured by a professional news camera at an official event.
#
# **Location:** A stage in a large venue. The blue backdrop features a geometric design and the NATO logo is visible in the top left corner. This suggests the video was filmed at a NATO summit.
#
# **Time:**  Daytime, judging by the lighting.
#
# **0:00-0:02:**  U.S. President Joe Biden walks into the frame from the right, approaching NATO Secretary-General Jens Stoltenberg who is standing still, slightly left of center. Both men are smiling and wearing dark suits.
#
# **0:02:** Biden and Stoltenberg shake hands.
#
# **Comments:**
#
# * The handshake suggests a cordial relationship between the two leaders.
# * The setting and formal attire point to the significance of the event.
#
# **Minimum Timing:** 2 seconds. This allows viewers to register who the individuals are and the context of the handshake.
#
# **Key Informational Part:** The handshake between Biden and Stoltenberg.
#
# **Rating:** 6/10. This shot is useful for establishing the presence of both leaders at the NATO summit. However, it lacks any significant action or dialogue, making it less impactful than other potential footage from the event.
#
# ## Analyzing clip 012
# Shot: Medium distance, handheld, somewhat shaky, likely captured by a news crew on the scene. The footage suggests a sense of immediacy.
# Location: A conference room, likely at the NATO summit in Vilnius, Lithuania, as suggested by the signs in the background.
# Time: Daytime, illuminated by artificial lighting.
# People: This clip shows NATO Secretary-General Jens Stoltenberg speaking with US President Joe Biden. They are surrounded by other people, likely aides and members of the press.
# 0:00-0:05
# Stoltenberg and Biden are shaking hands and smiling. They appear to be having a friendly conversation.  The camera pans slightly to the right, following Biden as he turns to speak to someone off-screen.
# Comments:
# The video captures a brief, friendly interaction between two world leaders.
# The presence of numerous cameras and the somewhat chaotic atmosphere suggest that this is a busy event with a lot of media attention.
# Minimum Timing: 0:00-0:03, this shows the handshake and the beginning of their conversation.
# Key Information: NATO Secretary-General Jens Stoltenberg speaking with US President Joe Biden.
# Rating: 6/10, the footage is of decent quality and shows a relevant interaction, but it's very brief and doesn't contain any sound, which limits its usefulness.
#
# ## Analyzing clip 023_1
# ## Video Clip Description:
#
# **Shot:** Medium distance, stable shot, likely captured by a professional news camera at an official event.
#
# **Location:**  A large hall or conference center, identifiable by the blue backdrop and formal attire of the individuals present. The presence of Donald Trump, Angela Merkel, and Boris Johnson suggests this is an international summit, likely a NATO or G7 meeting.
#
# **Time:**  Daytime, judging by the lighting and lack of any indication of artificial illumination.
#
# **0:00-0:03:**  The shot focuses on Donald Trump, Angela Merkel, and an unidentified man in a suit. Trump appears to be talking to someone off-camera to his right. Merkel is to his left, engaged in conversation with someone off-screen. The unidentified man gestures with his right hand, seemingly directing someone to Trump's right.
#
# **0:03-0:05:**  Boris Johnson enters the frame from the right, walking behind Trump. The unidentified man briefly places his hand on Trump's back, guiding him slightly to the right. Trump, still seemingly engaged in conversation, adjusts his trajectory slightly.
#
# **Comments:**
#
# * The clip captures a seemingly mundane moment of transition between events at a high-profile summit.
# * The unidentified man's gestures suggest a slight misdirection or confusion regarding the flow of movement. This is common in such choreographed events.
# * The presence of world leaders like Trump, Merkel, and Johnson makes the clip potentially useful for illustrating the atmosphere or behind-the-scenes interactions at the summit.
#
# **Minimum Timing:** 2-3 seconds. This allows viewers to register the presence of the key figures and the subtle interaction.
#
# **Rating:** 4/10. While the clip features recognizable world leaders, it lacks any significant event or interaction. It could be used as B-roll to establish the setting or context of the summit but wouldn't be strong enough to stand alone.
#
# ## Analyzing clip 010
# The video shows President Joe Biden speaking at a podium with the NATO logo. He is wearing a blue suit and a blue tie with white dots. He has a flag pin on his left lapel. He is standing in front of a blue backdrop with the NATO logo on either side of him. He is speaking about Russia.
#
# **Comments:**
#
# * **People:** President Joe Biden
# * **Location:** Unknown, likely a NATO summit
# * **Time:**  Unknown, daytime
# * **Shot:** Medium shot, professionally filmed, stable
# * **Key Information:** President Biden speaking about Russia in the context of NATO. The specific content of his statement is not fully clear from this short clip.
#
# **Minimum Timing:** 3 seconds to capture Biden and the context of the NATO backdrop.
#
# **Rating:** 5/10
#
# **Reason:** This clip provides a visual of President Biden addressing NATO, which could be useful for news reports related to US foreign policy or NATO-Russia relations. However, without the full context of his statement, the clip's informational value is limited. A longer clip with more of his speech would be more informative.
#
# ## Analyzing clip 004
# ## Video Description:
#
# **Shot:** Medium distance, static, professionally captured. The framing suggests a formal setting.
#
# **Location:**  Indoors, in front of a blue backdrop with repeating "NATO OTAN" logos. This strongly suggests an official NATO event.
#
# **Time:**  Daytime, illuminated by artificial lighting. The overall lighting is bright and even.
#
# **0:00-0:01**
# U.S. President Joe Biden and NATO Secretary General Jens Stoltenberg are shaking hands. Both men are smiling and appear to be engaging in friendly conversation.
#
# **Comments:**
#
# * The video captures a routine diplomatic interaction between two high-ranking officials.
# * The setting and the logos clearly indicate that the event is related to NATO.
# * The body language of both men suggests a positive and cooperative relationship.
#
# **Minimum Timing:** 0:01 - 0:02.  A quick shot is sufficient to convey the handshake.
#
# **Key Informational Part:** The handshake between Biden and Stoltenberg.
#
# **Rating:** 5/10. This footage is useful for establishing the presence of these leaders at a NATO event, but it lacks any significant action or newsworthy content on its own. It would serve better as B-roll footage to accompany other visuals and commentary.
#
# ## Analyzing clip 016
# ## Video Clip Description:
#
# **Shot:** Medium close-up, likely a static camera positioned for an interview setup. The framing suggests a formal and controlled environment.
#
# **Location:**  An office or formal meeting room. The presence of the US and Russian flags indicates a diplomatic setting, likely related to a meeting or summit.
#
# **Time:**  Undeterminable from the footage, but the setting suggests daytime.
#
# **People:** Vladimir Putin, President of Russia, is the sole focus. He is seated and wearing a dark suit and a burgundy tie. He appears to be listening to someone off-camera and reacting with a combination of amusement and slight awkwardness.
#
# **0:00-0:05:** Putin listens to the off-camera speaker, his expression shifting between a slight smile and a more neutral, almost bemused look. He occasionally nods subtly, acknowledging the speaker.
#
# **Comments:**
#
# * The clip captures a candid moment of Putin, offering a glimpse into his demeanor during a diplomatic engagement.
# * The absence of audio makes it difficult to interpret the context fully. The viewer is left to speculate about the nature of the conversation and what might be causing Putin's reaction.
# * The flags in the background provide important contextual information, indicating the involvement of Russia and the United States.
#
# **Minimum Timing:** 2-3 seconds. While the clip is short, it's important to show Putin's reaction for a brief moment to register his demeanor.
#
# **Key Informational Part:** Putin's subtle facial expressions and body language.
#
# **Rating:** 4/10. The clip is of decent quality and offers a glimpse into Putin's personality, which could be useful for illustrating his diplomatic style. However, the lack of audio significantly limits its informational value. Without context, it's difficult to draw any strong conclusions or use it as a standalone element in a news report.
#
# ## Analyzing clip 023_2
# Shot: Wide, stationary, professionally captured. The footage suggests a formal event of significance.
#
# Location: The video takes place on a stage with a blue backdrop featuring the hashtag "#WEARENATO," indicating a NATO summit. The presence of individuals like Donald Trump, Boris Johnson, and Angela Merkel confirms this as a high-level political gathering.
#
# Time: The video takes place under bright, artificial lighting, typical of indoor events and conferences.
#
# **0:00-0:05**
#
# World leaders, including Donald Trump, Boris Johnson, Angela Merkel, and others, are seen walking off the stage after a photo op. They are walking in a line, maintaining a formal procession.
#
# **Comments:**
#
# The key element of this clip is Trump briefly heading in the wrong direction before correcting himself. This moment provides a glimpse into Trump's sometimes unscripted behavior, even in formal settings.
#
# **Minimum Timing:** 0:00-0:05, to capture the leaders walking and Trump's misstep.
#
# **Rating:** 6/10. The clip offers a brief, humorous moment of a world leader making a minor gaffe. While not crucial to understanding the broader NATO summit, it could be used as a lighthearted cutaway in a longer news package about the event.
#
# ## Analyzing clip 022
# ## Video Description:
#
# **Shot:** Wide, static shot from a frontal perspective, likely captured by a professional camera crew at an official event. The framing suggests a formal and orchestrated setting.
#
# **Location:** A large conference hall or assembly room, indicated by the stage, backdrop, and professional lighting. The backdrop features the NATO logo, the number 70, and the words "London" and "Londres," suggesting a NATO summit taking place in London.
#
# **Time:**  Daytime, judging by the bright lighting and the formal attire of the individuals present.
#
# **0:00-0:02**
# The video shows a group of world leaders standing in three rows on a stage. They are posing for a group photo. All individuals are dressed in formal attire - suits for men and suits or dresses for women. Two drummers dressed in ceremonial British military attire stand at the foot of the stage, facing the camera.
#
# **Comments:**
#
# * The presence of the NATO branding and the formal attire strongly suggests this is a gathering of NATO leaders for a summit or significant meeting.
# * The number "70" likely commemorates an anniversary of NATO's founding.
# * Identifying the individuals present would be crucial for news purposes.
# * The static shot effectively captures the formality and importance of the event.
#
# **Minimum Timing:** 2-3 seconds. While a still shot, the presence of the drummers at the bottom frame adds a dynamic element that benefits from a slightly longer viewing time.
#
# **Rating:** 7/10. The clip provides a clear visual of what is likely a significant gathering of NATO leaders. However, its usefulness would be significantly enhanced by identifying the individuals present and providing context about the specific event.
#
# ## Analyzing clip 029
# ## Video Clip Description:
#
# **Shot:** Wide, static shot likely captured from a distance using a telephoto lens or drone. The framing suggests an observational perspective of a military exercise.
#
# **Location:** An open field with rolling hills and sparse vegetation. The terrain appears dry and dusty, possibly indicating a training ground or a region with a semi-arid climate.
#
# **Time:** Daytime, under clear skies. The bright sunlight casts distinct shadows, suggesting the time of day to be around mid-morning or afternoon.
#
# **0:00-0:06**
#
# Two armored vehicles, likely infantry fighting vehicles or light tanks, drive away from the camera towards the right side of the frame. They kick up a significant amount of dust as they traverse the uneven terrain. The vehicles maintain a consistent speed and distance from each other, suggesting a coordinated maneuver.
#
# **Comments:**
#
# * The video showcases a training exercise involving military vehicles, emphasizing their mobility and the impact on the environment.
# * The lack of visible markings or insignia on the vehicles makes it difficult to determine their specific nationality.
# * The dust clouds created by the vehicles add a sense of dynamism and scale to the scene, highlighting the power of the machinery.
#
# **Minimum Timing:** 0:00-0:04, this captures the movement of the vehicles and the dust clouds they generate.
#
# **Rating:** 6/10. This clip provides a visual representation of military exercises, which can be useful for illustrating news reports related to military activities, defense spending, or international relations. However, the lack of specific context and details about the exercise limits its overall informational value.
#
# ## Analyzing clip 026
# ## Video Clip Description:
#
# **Shot:** Medium-range, handheld, slightly shaky, likely captured by a news crew on the scene. The footage suggests a sense of urgency and potential danger.
#
# **Location:** A forested area with a visible road in the background. A fallen tree trunk is being used as a makeshift bridge or stepping stone. The presence of civilians with luggage suggests this could be a border crossing or an evacuation route.
#
# **Time:** Daytime, overcast sky. The natural lighting indicates this is a recent event.
#
# **0:00-0:03**
#
# The camera focuses on a group of people, including women and children, cautiously navigating a fallen tree trunk. They are being assisted by armed men in military fatigues, who appear to be helping them cross the obstacle. The civilians carry bags and suitcases, suggesting they are fleeing a dangerous situation.
#
# **Comments:**
#
# * The video captures the human impact of a conflict, showing civilians, including vulnerable individuals, being forced to flee their homes.
# * The presence of armed men in military fatigues suggests an active conflict zone or a situation of heightened security.
# * The fallen tree trunk could be a natural obstacle or a deliberate attempt to hinder movement in the area.
# * The civilians' expressions and body language convey fear and uncertainty.
#
# **Minimum Timing:** 0:00-0:05, this establishes the scene and the interaction between the civilians and the armed men.
#
# **Rating:** 9/10, the footage is powerful and emotionally resonant, providing a glimpse into the human cost of conflict. It would be highly valuable for news reports covering conflict zones, refugee crises, or humanitarian efforts.
#
# ## Analyzing clip 027_0
# ## Video Clip Description:
#
# **Shot:** Medium-close, handheld, shaky footage. The perspective appears to be from someone standing on the ground near the moving tanks. This amateur-style footage suggests it could be from a civilian's perspective or potentially from a soldier's viewpoint.
#
# **Location:**  An unidentified dirt road. The presence of trees and the lack of urban structures suggest a rural location. The overall bleak and overcast lighting further adds to the somber atmosphere.
#
# **Time:**  Unclear, likely daytime due to the available natural light.
#
# **0:00-0:04:** The primary subject is a Russian T-72 tank moving towards the camera. It has distinctive "V" markings painted on its armor, a common tactic used by Russian forces during the 2022 Ukraine conflict. The tank is followed by at least one other tank in the background, also bearing similar markings. Smoke or dust hangs in the air, indicating recent movement or nearby activity.
#
# **Comments:**
#
# * The "V" markings on the tanks are crucial for identifying them as part of the Russian forces.
# * The shaky camera work and low-quality footage suggest this could be citizen journalism or footage taken under duress.
# * The lack of identifying landmarks makes it difficult to pinpoint the exact location.
#
# **Minimum Timing:** 3-4 seconds to establish the subject (the tank), the "V" markings, and the overall atmosphere.
#
# **Rating:** 6/10. While the footage is not visually stunning, it holds informational value for news reports about the ongoing conflict. The presence of the "V" markings on the tanks offers valuable context about the parties involved. However, the lack of a specific location and the shaky, amateur-style filming detract from its overall quality and impact.
#
# ## Analyzing clip 020
# ## Video Description:
#
# **Shot:** Medium distance, static, professionally captured at an official event.
#
# **Location:**  In front of a blue backdrop with the NATO summit logo. The specific location is Brussels, as indicated by the banner on the right side of the screen.
#
# **Time:**  Daytime, likely during the NATO Summit held in Brussels on July 11-12, 2018.
#
# **People:**
#
# * **Donald Trump:** Then President of the United States, stands on the left side of the screen. He is wearing a dark suit with a red tie and has a neutral expression.
# * **Jens Stoltenberg:** NATO Secretary General, stands on the right. He is wearing a dark suit with a light blue shirt and a dark tie. He is smiling.
#
# **0:00-0:02:** Donald Trump and Jens Stoltenberg shake hands.
#
# **0:02-0:03:** Both men turn slightly towards the camera and maintain their positions.
#
# **Comments:** This is a standard handshake photo opportunity at an official event. The backdrop clearly identifies the event as a NATO summit. The presence of Donald Trump, then U.S. President, signifies the importance of the event.
#
# **Minimum Timing:** 2 seconds would be sufficient to show the handshake and the context of the event.
#
# **Rating:** 6/10 - This clip is useful for establishing the setting and participants of the NATO summit. However, it lacks any significant action or dialogue, making it less engaging for a news report. It could be used as a cutaway shot or as part of a montage.
#
# ## Analyzing clip 031
# ## Video Clip Description:
#
# **Shot:** Medium-range, static shot. The framing suggests the footage might be captured by a journalist or documentary filmmaker, focusing on a specific element within a larger event.
#
# **Location:** Outdoors, likely a military base or training ground. The presence of military vehicles and uniformed personnel strongly suggests this. The terrain appears to be hilly, possibly indicating a location in Europe or North America.
#
# **Time:** Daytime, under clear skies. The bright natural lighting provides good visibility of the scene.
#
# **0:00-0:03:**
#
# * The focus is on a group of four soldiers in US Army camouflage uniforms. They stand behind a table draped with a US flag.
# * Two soldiers are positioned on each side of the flag. The two soldiers on the right are armed with rifles.
# * In front of the soldiers on the left, two informational posters are visible. One features a Humvee, the other a Bradley Fighting Vehicle.
# * A similar poster for the Bradley Fighting Vehicle is also visible in front of the soldiers on the right.
# * The soldiers stand at attention, their faces mostly obscured by helmets and partially by face coverings.
#
# **Comments:**
#
# * The video highlights the US military presence, emphasizing their equipment and personnel.
# * The posters suggest an informational or promotional context, possibly related to a military exercise or demonstration.
# * The static shot lacks action, making it more suitable as B-roll footage to accompany narration or interviews.
#
# **Minimum Timing:** 2-3 seconds. This allows viewers to register the key elements – the soldiers, the flag, and the military vehicles in the background.
#
# **Rating:** 5/10. The clip provides a glimpse into a potential military event but lacks inherent action or narrative. Its usefulness depends heavily on the surrounding context provided by other footage and narration. It could be valuable for illustrating the US military's participation in an exercise or showcasing their equipment.
#
# ## Analyzing clip 032
# ## Video Clip Description:
#
# **Shot:** Medium close-up, still shot, likely captured by a news crew on the scene.
#
# **Location:** An outdoor environment, likely a military training ground or base. The presence of a military vehicle and camouflage netting suggests this.
#
# **Time:** Daytime, natural lighting.
#
# **0:00-0:07**
#
# The camera focuses on a U.S. soldier standing in front of a military vehicle. He is wearing a helmet with a mounted camera, sunglasses, and a standard camouflage uniform. His name tag reads "Gatica." He has a neutral expression on his face.
#
# A NATO patch is visible on his left shoulder. Another soldier's arm is partially visible to the right, also bearing a NATO patch. The vehicle behind them is partially obscured by camouflage netting.
#
# **Comments:**
#
# * The video focuses on the U.S. soldier and the NATO patch, highlighting the involvement of U.S. troops and the NATO alliance.
# * The soldier's neutral expression and the still camera angle do not reveal much emotion or action.
# * The background offers some context, suggesting a military setting.
#
# **Minimum Timing:** 2-3 seconds. As it is a still shot with minimal information, it doesn't require a long duration.
#
# **Rating:** 4/10.
#
# **Reason:** While the clip clearly shows a U.S. soldier with a NATO patch, potentially relevant to a news report about NATO activities, it lacks action or context. The still frame and limited background information make it less engaging for viewers. A panning shot showcasing more of the environment or soldiers interacting would be more informative and visually appealing.
#
# ## Analyzing clip 027_1
# ## Video Clip Description:
#
# **Shot:** Handheld, shaky, and taken from a low angle. This suggests the footage was likely captured by someone in or very near the moving convoy, not a professional news crew.
#
# ...
#
# ## Analyzing clip 040_1
# The video shows a still shot of a letter typed on white paper.
#
# **Comments:**
#
# * **Shot:** Still shot, likely a scan or a photograph.
# * **Content:** The letter is addressed to "Fellow Democrats" and dated July 8, 2024. It appears to be from a political figure, possibly running for office, who is reaffirming their commitment to the race. The individual claims to have the support of the Democratic party and voters. The name "Donald Trump" is mentioned in the last paragraph, suggesting this might be related to a presidential election.
# * **Key Information:** The date and the mention of "Donald Trump" are key pieces of information. The date sets the context within the 2024 election cycle, and the mention of Donald Trump suggests this is related to the US Presidential election.
#
# **Minimum Timing:** 2-3 seconds. As it's a still image, it shouldn't be on screen for too long to avoid boring the viewer.
#
# **Rating:** 6/10.
#
# * **Reasoning:** While the content of the letter is potentially newsworthy, the still image format is static. The information within the letter would be better conveyed through other visuals or graphics. The value of the clip depends heavily on the surrounding context and how the information is presented.
#
# ## Analyzing clip 036_0
# Shot: Extremely close up, still shot, likely captured by a news crew or someone documenting a document.
#
# Location: Unclear, likely an office or newsroom. The background is out of focus, and the surface the document is resting on appears to be a wood-grain desk.
#
# Time: Unknown
#
# 0:00-0:04
# The video displays a document that has been signed "Joseph R. Biden Jr. President of the United States"
#
# Comments:
# This video clip is a very standard close-up shot of a document.
#
# Minimum Timing: 2 seconds. This is enough time for the viewer to recognize whose signature it is.
#
# Key Informational Part: The clip shows that the document was signed by President Biden.
#
# Rating: 4/10. This type of shot is common in news reports, but is only moderately useful. It could be used to emphasize the importance of a document, or to verify its authenticity. However, it does not provide much context or information on its own.
#
# ## Analyzing clip 042_0
# Shot: Still shot of a letter. The camera is zoomed in on a section of the letter.
#
# Content: The letter is a statement from Joe Biden, presumably addressing his decision to remain in the 2020 Democratic primary race. The visible text emphasizes the democratic process and the voters' role in selecting the nominee.
#
# Key phrase: "Do we now just say this process didn't matter? That the voters don't have a say?"
#
# Minimum Timing: 3 seconds. This allows enough time for viewers to read the key phrase.
#
# Rating: 6/10.
#
# Comments: While not visually engaging, the text provides valuable insight into Biden's mindset. It could be used in a news report to underscore his defiance and commitment to the democratic process. However, the lack of visuals might make it less compelling than a video clip of Biden speaking directly.
#
# ## Analyzing clip 042_1
# Shot: Close up, still shot of a letter. The shot is professionally done and clearly legible.
#
# Location: Unknown
#
# Time: Unknown
#
# 0:00-0:07
# The camera is focused on a segment of a letter that reads, "Do we now just say this process didn't matter? That the voters don't have a say?" The letter is written in response to people saying that Biden should drop out of the 2020 Presidential race.
#
# Comments:
# This is a statement from Joe Biden, presumably from 2020 during his campaign.
#
# Minimum Timing: 2 seconds. This is a still shot, but the text is important to understand the context.
#
# Rating: 7/10. This is a strong quote from Biden during the 2020 election, and would be useful in a variety of situations. However, it is unknown who Biden is responding to, so further context would be needed.
#
# ## Analyzing clip 038_1
# The video shows a letter dated July 8, 2024, seemingly written by U.S. President Joe Biden to fellow Democrats.
#
# **Shot:** Still shot of a letter. The camera is stable and appears to be professionally filmed.
#
# **Location:** Unknown. The letter is on a table, but there is no indication of the location.
#
# **Time:** Unknown, but the letter is dated July 8, 2024.
#
# **Key Information:** The most important part of the clip is the first paragraph of the letter, where Biden states, "I am firmly committed to staying in this race, to running this race to the end, and to beating Donald Trump." This clearly indicates Biden's decision to seek re-election.
#
# **Minimum Timing:** 3-5 seconds. This is enough time for viewers to read the date and the key sentence in the first paragraph.
#
# **Rating:** 7/10. This clip is important because it confirms Biden's re-election bid. However, it is a still shot of a letter, which is not as visually engaging as a video clip of Biden speaking.
#
# ## Analyzing clip 043_0
# The video shows a letter from President Joe Biden. The shot is a still close-up of the signature at the end of the letter.
#
# **Minimum Timing:** 1-2 seconds. This is enough time for viewers to recognize it is a signature.
#
# **Key Informational Part:** The signature itself, confirming the letter is from President Biden.
#
# **Rating:** 2/10. While the content is relevant, visually it's not very interesting. A still shot of a signature doesn't offer much for a news report. It would be more impactful to feature the letter's content itself.
#
# ## Analyzing clip 042_2
# This is not a video, it is a still image of text. The text reads:
#
# "...left the primaries to run as an independent. Another attack ad. The voters of the Democratic Party have voted. He was soundly defeated. The voters of the Democratic Party have chosen the nominee of the party.
#
# This process didn't matter? That the voters don't have a say?
#
# ...feel a deep obligation to the faith and the trust the voters of this state put in me to run this year. It was their decision to make. Not the proprietors, not any selected group of individuals, no matter how powerful – and the voters alone – decide the nominee of the Dem..."
#
# Minimum Timing: As this is a still image, 2 seconds would be appropriate.
#
# Key Informational Part: The key information is the question "This process didn't matter? That the voters don't have a say?" as it seems to be the core argument being made.
#
# Rating: 4/10. While the content is relevant to understanding the context of a political race, as a still image it lacks visual appeal and dynamism. It would be more impactful if it was part of a video featuring the speaker or related imagery.
#
# ## Analyzing clip 044_0
# Shot: Close-up, still, likely captured by a news crew or someone documenting a speech or document. The footage suggests a sense of importance and urgency.
#
# Location: Unclear, likely an office or home office. The background is neutral and does not provide any clues to the specific location.
#
# Time: Unknown, but the lighting appears to be indoor lighting.
#
# 0:00-0:04
# The camera focuses on a typed letter that reads, "My fellow Democrats - we have the record, the vision, and our Democracy to win." The text continues below, but the camera does not move to show the rest of the message.
#
# Comments:
# The video captures a close-up of a message that seems to be directed at fellow Democrats. The visible text emphasizes the high stakes, mentioning "the record," "the vision," "our Democracy," and "to win."
#
# Minimum Timing: 0:00-0:02, this is enough time to read the visible text.
#
# Key Informational Part: The phrase "we have the record, the vision, and our Democracy to win," which highlights the message's themes of responsibility, hope, and potential victory.
#
# Rating: 4/10, the footage is somewhat useful for a news report if it's about the person or group who wrote the letter. It provides a glimpse into their message and potential strategies. However, without further context, the impact is limited. The still nature of the shot and the limited visible text reduce its overall value.
#
# ## Analyzing clip 044_1
# Shot: Close-up, still shot of a document. The camera is zoomed in on the text, suggesting a focus on the content and message.
#
# Location: Unclear, likely an office or home setting. The neutral background provides no clues about the specific location.
#
# Time: Unknown, as the lighting is artificial and doesn't offer any temporal cues.
#
# **0:00-0:04**
#
# The camera focuses on a typed paragraph on a piece of paper. The text reads: "We have the record, the vision, and the fundamental decency of our Democracy to win...move forward has been well-aired for over a year and 119 days to the general election. A drawn-out lead only helps Trump and hurts us. It is time to unite behind [unreadable] and defeat Donald Trump."
#
# **Comments:**
#
# The video highlights a key message within the document: the urgency to unite and defeat Donald Trump in an upcoming election. The mention of "119 days to the general election" suggests this document was created during a presidential campaign.
#
# **Minimum Timing:** 0:02-0:03. This allows enough time to read the key message about defeating Donald Trump.
#
# **Rating:** 6/10. The clip provides a glimpse into the sender's political strategy and concerns during a campaign. However, the lack of context (who wrote the document, to whom it was addressed) limits its usefulness for a news report. A longer excerpt showing the entire document or providing background information would be more informative.
#
# ## Analyzing clip 038_0
# The video shows a letter dated July 8, 2024, seemingly written by U.S. President Joe Biden to fellow Democrats.
#
# **0:00-0:04** The camera slowly pans across the top portion of the letter. The letterhead clearly shows "JOSEPH R. BIDEN, JR." and the date. The first paragraph is visible and reads: "Now that you have returned from the July 4th recess, I want you to know that despite the speculation in the press and elsewhere, I am firmly committed to staying in this race, to running this race to the end, and to beating Donald Trump."
#
# **Comments:**
#
# * **Shot:** Close-up, still shot. The camera is zoomed in on the letter, suggesting the content is of significance. The lack of movement implies a focus on the words themselves.
# * **Content:** The letter's date of July 8, 2024, indicates it was written during a hypothetical 2024 presidential election cycle. The mention of "speculation in the press" suggests Biden might be facing pressure to withdraw from the race. However, his statement about being "firmly committed" to staying and "beating Donald Trump" indicates his defiance and determination to continue campaigning.
#
# **Minimum Timing:** 3 seconds. This allows enough time for viewers to grasp the context (letter from Biden) and read the key statement about staying in the race.
#
# **Rating:** 7/10. This clip is informative as it reveals Biden's stance amidst potential doubts and challenges. It provides a strong visual element for news reports discussing the hypothetical 2024 election and Biden's campaign. However, it's a still shot of a document, which might not be as visually engaging as footage of Biden himself speaking.
#
# ## Analyzing clip 043_1
# Shot: Close-up, still shot of a letter. The camera focuses on the signature of the letter.
#
# Content: The image shows the end of a letter written by Joseph R. Biden Jr., President of the United States of America. The visible part of the content mentions "to beat Donald Trump" and "42 days to the Democratic Convention" suggesting the context is related to election campaigns.
#
# Minimum Timing: 2 seconds. While it's a still shot, the text content requires some time for viewers to grasp.
#
# Rating: 4/10. The still shot of the signature holds little visual interest for a news report. While it confirms the letter's origin, it lacks the dynamism of video footage and doesn't offer much visual storytelling.
#
# ## Analyzing clip 045_0
# Shot: Close-up, still shot, likely captured by a news crew.
#
# Content: The video shows a letter on White House letterhead. The visible text is a portion of the closing paragraph and signature of the letter. The signature reads "Joseph R. Biden Jr." with "Sincerely," above and "President of the United States" below. The visible portion of the text reads "...and we are asking Americans to join us in this moment by...".
#
# Comments: The still shot is of a letter seemingly written by President Biden. The content of the letter is not fully visible, only the signature.
#
# Minimum Timing: 2 seconds. This is enough time for viewers to read the signature and recognize the content.
#
# Rating: 4/10. The clip is short and does not reveal much information. It could be useful as a visual element in a news report about President Biden or a statement he has released, but it does not stand well on its own.
#
# ## Analyzing clip 045_1
# The video shows a close-up, slightly blurry shot of a letter on a desk. The camera is focused on the signature of the letter, which reads "Joseph R. Biden Jr." and "President of the United States". The content of the letter itself is mostly illegible, with only a few phrases like "defeat Donald Trump" and "historic record" discernible.
#
# **Comments:**
#
# * **Shot:** Close-up, static. The blurry nature of the shot suggests it might have been taken discreetly or in a hurry.
# * **Location:**  The setting appears to be an office or study, judging by the desk and the formal nature of the letter.
# * **Timing:** The entire clip is very short and doesn't offer much context. It's difficult to determine a specific time of day.
# * **Key Information:** The main takeaway is the visual confirmation of President Biden's signature on a letter, suggesting its authenticity. However, without further context about the letter's content and recipient, it's hard to gauge its significance.
#
# **Minimum Timing:** 2-3 seconds. This is enough time for viewers to register the signature and the "President of the United States" title.
#
# **Rating:** 4/10.
#
# **Reason:** While the clip confirms the letter's origin, its lack of context and brevity limit its usefulness. It could be used as a cutaway in a news report discussing the letter's content, but it doesn't stand well on its own. A higher-quality, more legible shot of the letter's content would significantly increase its value.
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')

# %%
print("Spell checking")
script.spell_check()
print("Generating facts")
script.generate_facts()
print("Generating script")
script.generate_script()
print("Generating lower thirds")
script.generate_lower_thirds()
print("Matching SOT clips")
script.match_sot_clips()

# print("Combining script")
# combined_script = script.with_combined_script()
# Out:
# Spell checking
# Generating facts
# ## Generating list of facts
# 1. Joe Biden is facing pressure in his reelection campaign, including concerns about his age and ability to serve.
#
# 2. Biden remains committed to staying in the race and beating Donald Trump, despite calls from some Democrats to end his campaign.
#
# 3. Biden challenged doubters to contest him at the Democratic National Convention in August.
#
# 4. The president is embarking on a voter outreach blitz, including trips to battleground states like Pennsylvania.
#
# 5. The Democratic Party is launching a $50 million media campaign involving Biden, his family, and other top officials.
#
# 6. A NATO summit is beginning in Washington on July 9, presenting both opportunities and risks for Biden.
#
# 7. Key issues at the NATO summit include Russia's invasion of Ukraine, protecting new NATO members Sweden and Finland, and addressing threats from China.
#
# 8. There is concern among NATO allies about the possibility of a second Trump term.
#
# 9. Some Democratic representatives have publicly called for Biden to end his campaign.
#
# 10. Biden describes himself as the most pro-union president in American history.
#
# 11. Biden plans to push for a fairer tax system in his second term, criticizing the current low tax rates for billionaires.
#
# 12. Biden opposes Trump's proposed $5 trillion tax cut, preferring to spend money on child care and elder care.
#
# 13. Biden is known for wearing Rayban sunglasses and liking chocolate chip ice cream.
#
# 14. The NATO summit is expected to focus on supporting Ukraine.
#
# 15. There is anxiety among NATO allies about the U.S. election and political developments in Europe.
#
# 16. Biden's popularity on the global stage and efforts to rebuild alliances are seen as strengths against Trump.
#
# 17. Trump has made controversial statements about NATO, including suggesting he wouldn't protect allies who don't pay enough for defense.
#
# 18. Ukraine's situation will dominate conversations at the NATO summit.
#
# 19. NATO is updating its operational plans to protect new members Finland and Sweden, as well as other countries bordering Russia or Belarus.
#
# 20. China's support for Russia and the potential threat it poses will be discussed at the summit.
#
# 21. Sweden recently joined NATO, with U.S. Secretary of State Antony Blinken accepting their instruments of accession.
#
# 22. Biden wrote a letter to Congress reaffirming his commitment to the race and addressing concerns about the election.
# Generating script
# ## Writing story
# U.S. President Joe Biden finds himself at a critical juncture in his reelection campaign as he faces mounting pressure from fellow Democrats and prepares for a high-stakes NATO summit in Washington. The 81-year-old incumbent has been dogged by concerns about his age and ability to serve another term following a halting performance in a June 27 debate with Republican rival Donald Trump.
# Despite growing calls from within his own party to end his reelection bid, Biden remains defiant. "I want you to know that despite all the speculation in the press and elsewhere, I am firmly committed to staying in this race, to running this race to the end, and to beating Donald Trump," Biden wrote to lawmakers as they returned from the July 4 recess.
# The president's resolve was further emphasized during a phone call to MSNBC's Morning Joe program, where he stated, "The bottom line here is that I am not going anywhere." He even challenged doubters to contest him at the Democratic National Convention in August, though such an effort stands little chance of success.
# As pressure mounts, Biden has embarked on a voter outreach blitz, including his 10th trip to the crucial battleground state of Pennsylvania during the 2024 election cycle. On Sunday, July 7, he campaigned in Harrisburg at an event with union members and local Democrats. This push is part of a broader $50 million media campaign by the Democratic Party, aimed at events such as the Olympics and involving travel by the president, first lady, Vice President Kamala Harris, and her husband to every battleground state.
# The upcoming NATO summit in Washington, beginning on July 9, presents both an opportunity and a risk for Biden. While it could allow him to showcase his leadership on the global stage and alleviate concerns about his health, it could also spotlight any potential weaknesses. The summit agenda includes critical issues such as Russia's invasion of Ukraine, protecting new NATO members Sweden and Finland, and addressing threats posed by China.
# However, looming over the summit is concern among alliance members about the U.S. election and the possibility of a second Trump term, given the former president's contentious relationship with allies during his first term.
# As Biden navigates these challenges, he faces dissent within his own party. Representatives Adam Smith and Lloyd Doggett have publicly called for Biden to end his campaign, citing concerns about his performance in polls against Trump and other Democratic candidates in key states.
# With donors mulling their willingness to continue funding Biden's campaign and pressure from Congress expected to intensify, the president faces a pivotal moment in his bid for reelection. As he prepares to host world leaders and hold a rare solo news conference, all eyes will be on Biden to see if he can quell doubts about his candidacy and maintain his grip on the Democratic nomination.
# ## Inserted SOTs
# U.S. President Joe Biden finds himself at a critical juncture in his reelection campaign as he faces mounting pressure from fellow Democrats and prepares for a high-stakes NATO summit in Washington. The 81-year-old incumbent has been dogged by concerns about his age and ability to serve another term following a halting performance in a June 27 debate with Republican rival Donald Trump.
#
# (SOUNDBITE)(English) SENIOR FELLOW AT THE COUNCIL ON FOREIGN RELATIONS AND PROFESSOR OF INTERNATIONAL AFFAIRS AT GEORGETOWN UNIVERSITY, CHARLES KUPCHAN, SAYING:
# "It is important for the American electorate to know whether Biden is in good shape, and what we saw at the debate was an aberration, a one-off, or whether there is a more systematic decline. And that kind of more systematic decline would probably be apparent over a course of a seven-day summit of this sort."
#
# Despite growing calls from within his own party to end his reelection bid, Biden remains defiant. "I want you to know that despite all the speculation in the press and elsewhere, I am firmly committed to staying in this race, to running this race to the end, and to beating Donald Trump," Biden wrote to lawmakers as they returned from the July 4 recess.
#
# The president's resolve was further emphasized during a phone call to MSNBC's Morning Joe program, where he stated, "The bottom line here is that I am not going anywhere." He even challenged doubters to contest him at the Democratic National Convention in August, though such an effort stands little chance of success.
#
# As pressure mounts, Biden has embarked on a voter outreach blitz, including his 10th trip to the crucial battleground state of Pennsylvania during the 2024 election cycle. On Sunday, July 7, he campaigned in Harrisburg at an event with union members and local Democrats. This push is part of a broader $50 million media campaign by the Democratic Party, aimed at events such as the Olympics and involving travel by the president, first lady, Vice President Kamala Harris, and her husband to every battleground state.
#
# The upcoming NATO summit in Washington, beginning on July 9, presents both an opportunity and a risk for Biden. While it could allow him to showcase his leadership on the global stage and alleviate concerns about his health, it could also spotlight any potential weaknesses. The summit agenda includes critical issues such as Russia's invasion of Ukraine, protecting new NATO members Sweden and Finland, and addressing threats posed by China.
#
# (SOUNDBITE)(English) SENIOR FELLOW AT THE COUNCIL ON FOREIGN RELATIONS AND PROFESSOR OF INTERNATIONAL AFFAIRS AT GEORGETOWN UNIVERSITY, CHARLES KUPCHAN, SAYING:
# "Ukraine will dominate the conversation, as it should. There is a major war going on. The Ukrainians suffered through a delay in the arrival of American aid, about seven months while Congress debated what turned out to be a $61 billion package. The armaments that are bought with that money have been arriving. They are getting to the front and that is enabling Ukraine to hold the line."
#
# However, looming over the summit is concern among alliance members about the U.S. election and the possibility of a second Trump term, given the former president's contentious relationship with allies during his first term.
#
# (SOUNDBITE) (English) FORMER U.S. PRESIDENT DONALD J. TRUMP SAYING:
# "One of the presidents of a big country, he stood up, said, 'Well, sir, if we don't pay and we're attacked by Russia, will you protect us?' I said, 'You didn't pay? You're delinquent?' He said, 'Yes, let's say that happened.' (AND TRUMP SAYS HE RESPONDED:) 'No, I would not protect you. In fact, I would encourage them to do whatever the hell they want. You got to pay. You got to pay your bills.' "
#
# As Biden navigates these challenges, he faces dissent within his own party. Representatives Adam Smith and Lloyd Doggett have publicly called for Biden to end his campaign, citing concerns about his performance in polls against Trump and other Democratic candidates in key states.
#
# With donors mulling their willingness to continue funding Biden's campaign and pressure from Congress expected to intensify, the president faces a pivotal moment in his bid for reelection. As he prepares to host world leaders and hold a rare solo news conference, all eyes will be on Biden to see if he can quell doubts about his candidacy and maintain his grip on the Democratic nomination.
# ## Edited story
# U.S. President Joe Biden faces a critical test as he prepares to host a high-stakes NATO summit in Washington, beginning July 9. The 81-year-old incumbent views this summit as a crucial opportunity to showcase his leadership on the global stage amid concerns about his age and ability to serve another term.
#
# Despite growing calls from within his own party to end his reelection bid, Biden remains defiant. "I am firmly committed to staying in this race, to running this race to the end, and to beating Donald Trump," Biden wrote to lawmakers as they returned from the July 4 recess.
#
# The NATO summit agenda includes critical issues such as Russia's invasion of Ukraine, protecting new NATO members Sweden and Finland, and addressing threats posed by China. However, concerns about the U.S. election and the possibility of a second Trump term loom over the gathering.
#
# (SOUNDBITE)(English) SENIOR FELLOW AT THE COUNCIL ON FOREIGN RELATIONS AND PROFESSOR OF INTERNATIONAL AFFAIRS AT GEORGETOWN UNIVERSITY, CHARLES KUPCHAN, SAYING:
# "Ukraine will dominate the conversation, as it should. There is a major war going on."
#
# To counter doubts about his candidacy, Biden has launched a voter outreach blitz, including trips to crucial battleground states. This effort is part of a broader $50 million media campaign by the Democratic Party, aimed at reinforcing the president's leadership credentials both domestically and internationally.
#
# As Biden prepares to host world leaders and hold a rare solo news conference, the NATO summit represents a pivotal moment for his presidency. Success at the summit could bolster his standing on the world stage and potentially quell concerns about his ability to lead, while any missteps could intensify the pressure he faces at home. All eyes will be on the president as he navigates this critical juncture in his reelection campaign.
# ## Reformatted story
# U.S. President Joe Biden faces a critical test as he prepares to host a high-stakes NATO summit in Washington, beginning Tuesday. The eighty-one-year-old incumbent views this summit as a crucial opportunity to showcase his leadership on the global stage amid concerns about his age and ability to serve another term.
#
# Despite growing calls from within his own party to end his reelection bid, Biden remains defiant. Biden wrote to lawmakers as they returned from the July Fourth recess, "I am firmly committed to staying in this race, to running this race to the end, and to beating Donald Trump."
#
# The NATO summit agenda includes critical issues such as Russia's invasion of Ukraine, protecting new NATO members Sweden and Finland, and addressing threats posed by China. However, concerns about the U.S. election and the possibility of a second Trump term loom over the gathering.
#
# (SOUNDBITE)(English) SENIOR FELLOW AT THE COUNCIL ON FOREIGN RELATIONS AND PROFESSOR OF INTERNATIONAL AFFAIRS AT GEORGETOWN UNIVERSITY, CHARLES KUPCHAN, SAYING:
# "Ukraine will dominate the conversation, as it should. There is a major war going on."
#
# To counter doubts about his candidacy, Biden has launched a voter outreach blitz, including trips to crucial battleground states. This effort is part of a broader fifty million dollar media campaign by the Democratic Party, aimed at reinforcing the president's leadership credentials both domestically and internationally.
#
# As Biden prepares to host world leaders and hold a rare solo news conference, the NATO summit represents a pivotal moment for his presidency. Success at the summit could bolster his standing on the world stage and potentially quell concerns about his ability to lead, while any missteps could intensify the pressure he faces at home. All eyes will be on the president as he navigates this critical juncture in his reelection campaign.
# Generating lower thirds
# INFO: Headline was too long, shortening: Biden Faces Crucial NATO Summit Amid Age Concerns
# ## Generating headline
# Biden Hosts NATO Summit Amid Age Doubts
# ## Generating loglines
# 1: Biden hosts NATO summit amid age fears
#
# 2: Biden defiant on 2024 run vs. Trump
#
# 3: NATO tackles Russia, China amid US woes
#
# 5: Biden launches $50M campaign blitz
#
# 6: NATO summit: Biden's pivotal moment
# ## Generating bylines
# 4: Charles Kupchan, Senior Fellow At The Council On Foreign Relations And Professor Of International Affairs At Georgetown University
# Matching SOT clips
# ## Matched SOT
# Found quote in clip 028. From 0s to 30s. Ukraine will dominate the conversation, as it should. There is a major war going on.

# %%
audio_processor = AudioProcessor(script, clip_manager, story_folder, error_handler)
print("Processing anchor audio")
audio_processor._process_anchor_audio()
print("Generating SOT translations")
audio_processor._generate_sot_translations()
print("Adding B-roll placements")
audio_processor._add_broll_placements()
# Out:
# 2024-07-09 00:34:13.378 No runtime found, using MemoryCacheStorageManager
# Processing anchor audio
# ## Generating anchor audio
# U.S. President Joe Biden faces a critical test as he prepares to host a high-stakes NATO summit in Washington, beginning Tuesday. The eighty-one-year-old incumbent views this summit as a crucial opportunity to showcase his leadership on the global stage amid concerns about his age and ability to serve another term.
# ## Generating anchor audio
# Despite growing calls from within his own party to end his reelection bid, Biden remains defiant. Biden wrote to lawmakers as they returned from the July Fourth recess, 'I am firmly committed to staying in this race, to running this race to the end, and to beating Donald Trump.'
# ## Generating anchor audio
# The NATO summit agenda includes critical issues such as Russia's invasion of Ukraine, protecting new NATO members Sweden and Finland, and addressing threats posed by China. However, concerns about the U.S. election and the possibility of a second Trump term loom over the gathering.
# ## Generating anchor audio
# To counter doubts about his candidacy, Biden has launched a voter outreach blitz, including trips to crucial battleground states. This effort is part of a broader fifty million dollar media campaign by the Democratic Party, aimed at reinforcing the president's leadership credentials both domestically and internationally.
# ## Generating anchor audio
# As Biden prepares to host world leaders and hold a rare solo news conference, the NATO summit represents a pivotal moment for his presidency. Success at the summit could bolster his standing on the world stage and potentially quell concerns about his ability to lead, while any missteps could intensify the pressure he faces at home. All eyes will be on the president as he navigates this critical juncture in his reelection campaign.
# Generating SOT translations
# Adding B-roll placements
# 2024-07-09 00:35:00.187 No runtime found, using MemoryCacheStorageManager
# ## Placing BROLL
# <response>
# **Section 1: 0 - 20.22**
# Transcript: U.S. President Joe Biden faces a critical test as he prepares to host a high-stakes NATO summit in Washington, beginning Tuesday. The eighty-one-year-old incumbent views this summit as a crucial opportunity to showcase his leadership on the global stage amid concerns about his age and ability to serve another term.
# Thoughts: This section introduces the upcoming NATO summit and highlights the challenges Biden faces. We should show visuals of Biden, the NATO summit logo, and perhaps some shots of world leaders.
#
# * **Anchor (max 10 seconds):** 0.00 - 5.00 - We start on an Anchor to introduce the story and set the scene.
# * **Clip 010 (max 7.37 seconds):** 5.00 - 12.37 - This clip shows Biden speaking at a NATO event, establishing his involvement and the summit's context.
# * **Clip 003 (max 2.37 seconds):** 12.37 - 14.74 -  Show Biden with Stoltenberg, highlighting key figures.
# * **Clip 022 (max 2.97 seconds):** 14.74 - 17.71 -  World leaders at a NATO summit, emphasizing the global stage.
# * **Anchor (max 10 seconds):** 17.71 - 20.22 - Transition back to Anchor to cover Biden's age concerns and the upcoming election.
#
# **Section 2: 20.22 - 37.43**
# Transcript: Despite growing calls from within his own party to end his reelection bid, Biden remains defiant. Biden wrote to lawmakers as they returned from the July Fourth recess, 'I am firmly committed to staying in this race, to running this race to the end, and to beating Donald Trump.'
# Thoughts: This section focuses on Biden's determination to stay in the race despite opposition. We can use shots of Biden looking determined, perhaps at a rally or meeting, and maybe a visual representation of the letter he wrote.
#
# * **Clip 035 (max 7.97 seconds):** 20.22 - 28.19 - Show the letter Biden wrote, emphasizing his message.
# * **Clip 038_0 (max 5.0 seconds):** 28.19 - 33.19 - Close-up of the letter, highlighting his commitment.
# * **Clip 042_1 (max 6.67 seconds):** 33.19 - 37.43 - More of the letter, emphasizing his defiance.
#
# **Section 3: 37.43 - 58.35**
# Transcript: The NATO summit agenda includes critical issues such as Russia's invasion of Ukraine, protecting new NATO members Sweden and Finland, and addressing threats posed by China. However, concerns about the U.S. election and the possibility of a second Trump term loom over the gathering.
# Thoughts: This section outlines the key issues on the NATO summit agenda, including the war in Ukraine and concerns about Trump's potential return. We should show footage related to these issues, such as images of the conflict in Ukraine, maps of NATO expansion, and possibly Trump at a rally.
#
# * **Clip 026 (max 3.97 seconds):** 37.43 - 41.40 - Footage of civilians fleeing conflict, highlighting the human cost of war in Ukraine.
# * **Clip 027_0 (max 4.37 seconds):** 41.40 - 45.77 - Russian tanks in Ukraine, illustrating the ongoing conflict.
# * **Clip 034_0 (max 4.37 seconds):** 45.77 - 50.14 - Sweden joining NATO, showing a key agenda item.
# * **Clip 020 (max 3.67 seconds):** 50.14 - 53.81 - Trump at a NATO summit, representing concerns about his potential return.
# * **Clip 016 (max 5.97 seconds):** 53.81 - 58.35 -  Transition to a shot of Putin to represent broader geopolitical tensions and the looming presence of his actions on the summit.
#
# **Section 5: 58.35 - 79.04**
# Transcript: To counter doubts about his candidacy, Biden has launched a voter outreach blitz, including trips to crucial battleground states. This effort is part of a broader fifty million dollar media campaign by the Democratic Party, aimed at reinforcing the president's leadership credentials both domestically and internationally.
# Thoughts: This section describes Biden's campaign efforts to address doubts and reinforce his leadership. We can show footage of Biden at campaign events, interacting with voters, and perhaps some graphics related to the media campaign.
#
# * **Clip 005 (max 2.57 seconds):** 58.35 - 60.92 - Biden interacting with people, showing his outreach efforts.
# * **Clip 031 (max 3.5 seconds):** 60.92 - 64.42 - While not directly a Biden rally, US soldiers at attention can represent bolstering national security, a key aspect of Biden's campaign.
# * **Anchor (max 10 seconds):** 64.42 - 74.42 - Since we don't have much B-roll for campaign events, use Anchor to cover the rest of the section, focusing on the media campaign and Biden's domestic and international efforts.
# * **Clip 032 (max 2.53 seconds):** 74.42 - 76.95 -  A US soldier with a NATO patch, subtly reinforcing the connection between domestic efforts and international alliances.
# * **Anchor (max 10 seconds):** 76.95 - 79.04 - Transition back to Anchor to smoothly move to the next section.
#
# **Section 6: 79.04 - 106.52**
# Transcript: As Biden prepares to host world leaders and hold a rare solo news conference, the NATO summit represents a pivotal moment for his presidency. Success at the summit could bolster his standing on the world stage and potentially quell concerns about his ability to lead, while any missteps could intensify the pressure he faces at home. All eyes will be on the president as he navigates this critical juncture in his reelection campaign.
# Thoughts: This section emphasizes the high stakes of the NATO summit for Biden's presidency and reelection campaign. We should show visuals of Biden preparing for the summit, interacting with world leaders, and perhaps some shots that convey the pressure he's under.
#
# * **Clip 004 (max 1.73 seconds):** 79.04 - 80.77 - Biden shaking hands with Stoltenberg, showing his preparation for the summit.
# * **Clip 012 (max 6.47 seconds):** 80.77 - 87.24 - Biden speaking with Stoltenberg, highlighting the importance of the summit.
# * **Clip 023_1 (max 5.51 seconds):** 87.24 - 92.75 - Biden with other world leaders, emphasizing the global stage.
# * **Clip 023_2 (max 5.51 seconds):** 92.75 - 98.26 -  The misstep of Biden walking the wrong way can subtly represent the potential for missteps mentioned in the audio.
# * **Anchor (max 10 seconds):** 98.26 - 106.52 - Transition back to Anchor to conclude the story, focusing on the pressure Biden faces and the critical juncture in his campaign.
# </response>
# WARNING: Short broll 032 in section 5 between anchors. Merged with surrounding anchors.

# %%
# STREAMLIT
from src.gcp import GCSManager
from src.constants import HEYGEN_API_KEY
from src.hashing import sha256sum, hash_audio_file, hash_ignore, hash_absolute_path
from src.error_handler import StreamlitErrorHandler, StdOutErrorHandler

import streamlit as st
# /STREAMLIT

import requests
import time
from pathlib import Path, PosixPath

@st.cache_data(show_spinner=False)
def get_heygen_avatars():
    url = "https://api.heygen.com/v2/avatars"
    headers = {
        "X-Api-Key": HEYGEN_API_KEY,
        "Content-Type": "application/json"
    }
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()
        return data["data"]["avatars"]
    else:
        raise Exception(f"Error fetching avatars: {response.status_code} - {response.text}")

# @st.cache_data(show_spinner=True, hash_funcs={PosixPath: hash_absolute_path, StreamlitErrorHandler: hash_ignore, StdOutErrorHandler: hash_ignore})
def animate_anchor(local_audio_file_path: Path, transcript: str, avatar_id: str, output_path: Path, avatar_style: str = 'normal', test: bool = True, error_handler=None):
    # Upload the local audio file to GCP and get the URL
    gcs = GCSManager()
    audio_url = gcs.upload_to_gcs_url(local_audio_file_path, local_audio_file_path.name,  "public-heygen-assets")
    
    # Define the request payload
    payload = {
        "video_inputs": [
            {
                "character": {
                    "type": "avatar",
                    "avatar_id": avatar_id,
                    "avatar_style": avatar_style
                },
                "voice": {
                    "type": "audio",
                    "audio_url": audio_url
                },
                "background": {
                    "type": "color",
                    "value": "#FFFFFF"
                }
            }
        ],
        "test": test,
        "aspect_ratio": "16:9"
    }
    
    # Define the headers
    headers = {
        "X-Api-Key": HEYGEN_API_KEY,
        "Content-Type": "application/json"
    }
    
    # Send the request to generate the video
    response = requests.post("https://api.heygen.com/v2/video/generate", json=payload, headers=headers)
    response_data = response.json()
    
    if response.status_code != 200 or response_data.get("error"):
        raise Exception(f"Error generating video: {response_data.get('error')}")
    
    video_id = response_data["data"]["video_id"]
    
    # Poll the status of the video until it is complete
    video_status_url = f"https://api.heygen.com/v1/video_status.get?video_id={video_id}"
    while True:
        status_response = requests.get(video_status_url, headers=headers)
        status_data = status_response.json()["data"]
        
        if status_data["status"] == "completed":
            gcs.clear_uploaded_blobs()
            video_url = status_data["video_url"]
            # Download the video
            video_response = requests.get(video_url)
            with open(output_path, 'wb') as video_file:
                video_file.write(video_response.content)
            return
        elif status_data["status"] == "failed":
            gcs.clear_uploaded_blobs()
            raise Exception(f"Video generation failed: {status_data.get('error')}")
        elif status_data["status"] in ["processing", "pending"]:
            # if error_handler:
            #     if status_data["status"] == "processing":
            #         error_handler.info("Heygen processing...")
            #     if status_data["status"] == "pending":
            #         error_handler.info("Heygen in queue...")
            time.sleep(10)  # Wait before polling again
        else:
            time.sleep(10)
# Out:
# 2024-07-09 00:46:58.460 No runtime found, using MemoryCacheStorageManager

# %%
# VideoEditor

# STREAMLIT
from src.clip_manager import ClipManager
from src.news_script import NewsScript, AnchorScriptSection, SOTScriptSection, is_type
from src.movie_utils import resize_image_clip, cap_loudness, cap_loudness_audio_clip, set_loudness, set_loudness_audio_clip
# from src.heygen import animate_anchor
import streamlit as st
# /STREAMLIT

from pathlib import Path
from typing import Dict, Tuple
import traceback

import moviepy.editor as mp
from moviepy.audio.fx.audio_loop import audio_loop
from PIL import Image, ImageDraw, ImageFont
import numpy as np

class VideoEditor:
    """Handles video editing, including assembling clips and B-roll."""

    def __init__(self, news_script: NewsScript, clip_manager: ClipManager,
                 live_anchor: bool, test_mode: bool, music: bool,
                 music_file: Path,
                 output_resolution: Tuple[int, int] = (1920, 1080),
                 bitrate: str = "10M",
                 font: Path = None, logo_path: Path = None,
                 logline_padding_ratio=1.0909, dub_volume_lufs=-40,
                 lower_volume_duration=1.5, dub_delay=0.5, error_handler=None):
        self.news_script = news_script
        self.clip_manager = clip_manager
        self.live_anchor = live_anchor
        self.test_mode = test_mode
        self.music = music
        self.music_file = music_file
        self.output_resolution = output_resolution
        self.bitrate = bitrate
        self.font = font
        self.logo_path = logo_path
        self.logline_padding = int((self.output_resolution[0] - (self.output_resolution[0] // logline_padding_ratio)) // 2)
        self.dub_volume_lufs = dub_volume_lufs
        self.lower_volume_duration = lower_volume_duration
        self.dub_delay = dub_delay
        self.error_handler = error_handler
        self.fps = 29.97

    def assemble_video(self, output_file: Path = Path("output.mp4")):
        """Assembles the final video from script sections and B-roll."""
        video_clips = []
        # STREAMLIT
        progress_bar = st.progress(0.0)
        for i, section in enumerate(self.news_script.sections):
            # try:
            if is_type(section, SOTScriptSection):
                if section.clip is not None:
                    video_clips.append(self._process_sot_section(section))
            elif is_type(section, AnchorScriptSection):
                if section.text:
                    video_clips.append(self._process_anchor_section(section))
            else:
                print(f"ERROR: Unknown section type: {type(section)}")
            progress_bar.progress((i+1) / len(self.news_script.sections))
            # except Exception as e:
            #     if self.error_handler:
            #         self.error_handler.warning(f"Error when assembling section {section.id}: {traceback.format_exc()}")

        logline = self.news_script.headline
        concat_video = mp.concatenate_videoclips(video_clips, method="compose")
        final_video = self._add_logline(concat_video, logline)
        if self.music:
            final_video = self._add_background_music(final_video)
        final_video = final_video.fadein((1.0/self.fps)*10).fadeout((1.0/self.fps)*10)

        st.write("Rendering final video file")
        if self.error_handler:
            self.error_handler.info("Rendering final video")
        final_video.write_videofile(str(output_file), fps=self.fps, threads=8,
                                    codec='libx264', audio_codec='aac',
                                    bitrate=self.bitrate, logger="bar")
        # /STREAMLIT

    def _process_sot_section(self, section: SOTScriptSection) -> mp.VideoFileClip:
        """Processes a SOTScriptSection, extracting and resizing the clip."""
        clip = section.clip.load_video()
        clip = resize_image_clip(clip, self.output_resolution)
        clip = set_loudness(clip)

        if section.dub_audio_file is None:
            clip = clip.subclip(section.start, min(section.end, clip.duration))
        else:
            clip = clip.subclip(section.start)
            dub_audio = mp.AudioFileClip(str(section.dub_audio_file))
            dub_audio = set_loudness_audio_clip(dub_audio)

            # 1. Calculate the time the dub starts
            dub_start_time = self.lower_volume_duration + self.dub_delay
            dub_end_time = dub_audio.duration + dub_start_time

            if dub_start_time > clip.duration:
                return clip

            # 2. Original audio with fadeout and lower volume
            original_audio = clip.audio
            original_audio = mp.concatenate_audioclips([
                original_audio.subclip(0, self.lower_volume_duration*1.1).audio_fadeout(self.lower_volume_duration*1.1).subclip(0, self.lower_volume_duration),
                cap_loudness_audio_clip(original_audio.subclip(self.lower_volume_duration, clip.duration), self.dub_volume_lufs).set_start(self.lower_volume_duration)
            ])

            # 3. Delayed dubbed audio
            delayed_dub_audio = dub_audio.set_start(dub_start_time)

            # 4. Combine original and dubbed audio
            new_audio = mp.CompositeAudioClip([original_audio, delayed_dub_audio])

            # 5. Adjust video speed if needed
            if clip.duration > dub_end_time:
                clip = clip.subclip(0, dub_end_time)
            elif clip.duration < dub_end_time:
                speed_factor = clip.duration / dub_end_time
                clip = clip.fx(mp.vfx.speedx, speed_factor)

                if self.error_handler:
                    self.error_handler.info(f"INFO: Section {section.id}, dubed SOT is too long. Slowing down SOT with factor {speed_factor}")

            # 6. Set new audio
            clip = clip.set_audio(new_audio)
            clip = clip.set_duration(dub_end_time)
        
        if section.is_interview():
            clip = self._add_byline(clip, section.name, section.title)
        clip = clip.subclip(0, clip.duration - 0.1)
        clip = clip.audio_fadein((1.0/self.fps)*2).audio_fadeout((1.0/self.fps)*2)
        return clip

    def _process_anchor_section(self, section: AnchorScriptSection) -> mp.VideoFileClip:
        """Processes an AnchorScriptSection, assembling B-roll and audio."""
        broll_clips = []
        for broll_info in section.brolls:
            if broll_info["id"] == "Anchor":
                broll_clip = self._load_and_process_anchor(broll_info, section)
            else:
                broll_clip = self._load_and_process_broll(broll_info)
            broll_clips.append(broll_clip)

        if not broll_clips:
            if self.error_handler:
                self.error_handler.warning(f"Anchor section {section.id} had no broll. Skipping section in final video.")
            return None
        combined_broll = mp.concatenate_videoclips(broll_clips, method="compose")
        voiceover_audio = mp.AudioFileClip(str(section.anchor_audio_file))

        if combined_broll.duration < voiceover_audio.duration:
            speed_factor = combined_broll.duration / voiceover_audio.duration
            if speed_factor > 0.7:
                if speed_factor < 0.99:
                    if self.error_handler:
                        self.error_handler.info(f"INFO: Brolls in section {section.id} are too short, adjusting speed ({speed_factor:.2f})")
                combined_broll = combined_broll.fx(mp.vfx.speedx, speed_factor)
            else:
                if self.error_handler:
                    self.error_handler.info(f"INFO: Brolls in section {section.id} are too short, adding Anchor shot")
                anchor_clip = self._load_and_process_anchor({"start": combined_broll.duration, "end": voiceover_audio.duration}, section)
                combined_broll = mp.concatenate_videoclips([combined_broll, anchor_clip], method="compose")

        combined_broll = combined_broll.set_audio(voiceover_audio)
        combined_broll = combined_broll.set_duration(voiceover_audio.duration)

        return combined_broll.subclip(0, combined_broll.duration - 0.1)
    
    def _load_and_process_anchor(self, broll_info: Dict, section: AnchorScriptSection) -> mp.VideoFileClip:
        if self.live_anchor:
            anchor_video_file = self.news_script.folder / f"{section.id}_anchor.mp4"
            print(section.anchor_audio_file)
            # animate_anchor(section.anchor_audio_file, section.text, self.clip_manager.get_anchor_avatar_id(), anchor_video_file, test=self.test_mode, error_handler=self.error_handler)
            if self.error_handler:
                self.error_handler.stream_status(section.text, title="Generated anchor video", video=anchor_video_file)
            anchor_clip = mp.VideoFileClip(str(anchor_video_file))

            anchor_start = broll_info['start']
            anchor_end = broll_info['end']

            anchor_clip = anchor_clip.subclip(anchor_start, anchor_end)
            anchor_clip = resize_image_clip(anchor_clip, self.output_resolution)
        else:
            anchor_clip = self.clip_manager.get_anchor_image_clip()
            duration = broll_info['end'] - broll_info['start']
            anchor_clip = anchor_clip.set_duration(duration)
            anchor_clip = resize_image_clip(anchor_clip, self.output_resolution)
        return anchor_clip

    def _load_and_process_broll(self, broll_info: Dict) -> mp.VideoFileClip:
        """Loads, processes (resizing, speed adjustment), and returns a B-roll clip."""
        clip = self.clip_manager.get_clip(broll_info['id'])
        broll_file = clip.file_path
        broll_clip = mp.VideoFileClip(str(broll_file))
        broll_clip = cap_loudness(broll_clip)

        broll_start = broll_info['start']
        broll_end = broll_info['end']
        broll_duration = broll_end - broll_start

        if broll_clip.duration < broll_duration:
            speed_factor = broll_clip.duration / broll_duration
            if speed_factor > 0.7:
                if speed_factor < 0.99:
                    if self.error_handler:
                        self.error_handler.info(f"INFO: Broll {broll_info['id']} is too short, adjusting speed ({speed_factor:.2f})")
                broll_clip = broll_clip.fx(mp.vfx.speedx, speed_factor)
            else:
                if self.error_handler:
                    self.error_handler.info(f"INFO: Broll {broll_info['id']} is too short, video will be slow ({speed_factor:.2f}).")
                broll_clip = broll_clip.fx(mp.vfx.speedx, speed_factor)

        broll_clip = broll_clip.subclip(0, min(broll_duration, broll_clip.duration))
        broll_clip = broll_clip.set_duration(broll_duration)
        broll_clip = resize_image_clip(broll_clip, self.output_resolution)
        return broll_clip
    
    def _add_byline(self, clip: mp.VideoFileClip, name: str, title: str) -> mp.VideoFileClip:
        """Adds a lower-third byline above the logline to the given clip."""

        output_width, output_height = clip.w, clip.h
        bottom_margin = 2

        byline_height = int(output_height * (162/1080))
        inner_content_height = int(byline_height * (82/162))
        byline_padding = (byline_height - inner_content_height) // 2

        top_inner_content_height = int(inner_content_height * (33/82))
        bottom_inner_content_height = int(inner_content_height * (25/82))
        middle_inner_content_spacing = inner_content_height - top_inner_content_height - bottom_inner_content_height

        name_text_clip = self._create_raw_text_clip(name.upper(), top_inner_content_height, (255, 255, 255, 255))
        title_text_clip = self._create_raw_text_clip(title.upper(), bottom_inner_content_height, (255, 255, 255, 255))

        inner_content_width = max(name_text_clip.w, title_text_clip.w)
        byline_width = inner_content_width + byline_padding * 2

        byline_x = self.logline_padding
        logline_height = int(output_height * (150/1080))
        byline_y = output_height - self.logline_padding - byline_height - logline_height - bottom_margin

        bg_clip = (
            mp.ColorClip(size=(byline_width, byline_height), color=(0, 5, 52, 255 * 0.9))
            .set_position(
                (byline_x, byline_y)
            )
            .set_duration(clip.duration)
        )

        name_x = byline_x + byline_padding
        name_y = byline_y + byline_padding

        name_text_clip = name_text_clip.set_position(
            (name_x, name_y)
        ).set_duration(clip.duration)

        title_x = byline_x + byline_padding
        title_y = byline_y + byline_padding + top_inner_content_height + middle_inner_content_spacing

        title_text_clip = title_text_clip.set_position(
            (title_x, title_y)
        ).set_duration(clip.duration)

        final_elements = [clip, bg_clip, name_text_clip, title_text_clip]
        return mp.CompositeVideoClip(final_elements)

    def _add_logline(self, clip: mp.VideoFileClip, logline_text: str) -> mp.VideoFileClip:
        """Adds a lower-third logline to the given clip."""

        output_width, output_height = clip.w, clip.h
        logo_logline_padding = 2

        # Calculate logline dimensions based on video resolution and padding
        logline_height = int(output_height * (150/1080))  # 10% of video height
        logline_width = output_width - self.logline_padding * 2
        if self.logo_path:
            logline_width -= logline_height
            logline_width -= logo_logline_padding

        logline_x = self.logline_padding
        logline_y = output_height - self.logline_padding - logline_height

        # 1. Create a white background ImageClip
        bg_clip = (
            mp.ColorClip(size=(logline_width, logline_height), color=(255, 255, 255, 255 * 0.9))
            .set_position(
                (logline_x, logline_y)
            )
            .set_duration(clip.duration)
        )

        # 2. Create text ImageClip
        text_clip = self._create_text_clip(logline_text.upper(), logline_width, logline_height)
        text_clip = text_clip.set_position(
            (logline_x, logline_y)
        ).set_duration(clip.duration)

        # 3. Load and position logo (if provided)
        if self.logo_path:
            logo = (
                mp.ImageClip(str(self.logo_path))
                .set_opacity(1.0)
                .resize(height=logline_height)
                .set_position(
                    (logline_x + logline_width + logo_logline_padding, logline_y)
                )
                .set_duration(clip.duration)
            )
            final_elements = [clip, bg_clip, text_clip, logo]
        else:
            final_elements = [clip, bg_clip, text_clip]

        # 4. Compose final clip
        return mp.CompositeVideoClip(final_elements)
    
    def _create_raw_text_clip(self, text: str, height: int, text_color = (0, 0, 0, 255)) -> mp.ImageClip:
        """Creates a transparent ImageClip with the given text."""
        ref_text_image = Image.new("RGBA", (1, height), (0, 0, 0, 0))
        ref_draw = ImageDraw.Draw(ref_text_image)

        def get_font_size_for_height(font_path, desired_height):
            font_size = 1
            font = ImageFont.truetype(font_path, font_size)
            text_bbox = ref_draw.textbbox((0, 0), "H", font=font)
            while text_bbox[3] - text_bbox[1] < desired_height:
                font_size += 1
                font = ImageFont.truetype(font_path, font_size)
                text_bbox = ref_draw.textbbox((0, 0), "H", font=font)
            return font_size - 1

        # Load the font
        if not self.font:
            font = ImageFont.load_default()
        else:
            font_path = str(self.font)
            font_size = get_font_size_for_height(font_path, height)
            font = ImageFont.truetype(font_path, font_size)

        ref_text_bbox = ref_draw.textbbox((0, 0), text, font=font)
        ref_text_width = ref_text_bbox[2] - ref_text_bbox[0]
        text_x = 0
        text_y = -ref_text_bbox[1]

        text_image = Image.new("RGBA", (ref_text_width, height), (0, 0, 0, 0))
        draw = ImageDraw.Draw(text_image)
        draw.text((text_x, text_y), text, font=font, fill=text_color)
        return mp.ImageClip(np.array(text_image))

    def _create_text_clip(self, text: str, width: int, height: int) -> mp.ImageClip:
        """Creates a transparent ImageClip with the given text."""
        text_image = Image.new("RGBA", (width, height), (0, 0, 0, 0))
        draw = ImageDraw.Draw(text_image)

        def get_font_size_for_height(font_path, desired_height):
            font_size = 1
            font = ImageFont.truetype(font_path, font_size)
            text_bbox = draw.textbbox((0, 0), "H", font=font)
            while text_bbox[3] - text_bbox[1] < desired_height:
                font_size += 1
                font = ImageFont.truetype(font_path, font_size)
                text_bbox = draw.textbbox((0, 0), "H", font=font)
            return font_size - 1

        # Load the font
        if not self.font:
            font = ImageFont.load_default()
        else:
            font_path = str(self.font)
            font_size = get_font_size_for_height(font_path, int(height * (59/150)))
            font = ImageFont.truetype(font_path, font_size)
        
        reference_char = "H"
        ref_text_bbox = draw.textbbox((0, 0), reference_char, font=font)
        ref_text_height = ref_text_bbox[3] - ref_text_bbox[1]

        # Get text size, adjust height, calculate position
        text_bbox = draw.textbbox((0, 0), text, font=font)
        text_width = text_bbox[2] - text_bbox[0]
        text_height = text_bbox[3] - text_bbox[1]
        text_x = self.logline_padding // 2
        text_y = -ref_text_bbox[1] + (height - ref_text_height) // 2

        # Draw the text
        draw.text((text_x, text_y), text, font=font, fill=(0, 0, 0, 255))

        return mp.ImageClip(np.array(text_image))
    
    def _add_background_music(self, video: mp.VideoClip) -> mp.VideoClip:
        background_music = mp.AudioFileClip(str(self.music_file))
        background_music = cap_loudness_audio_clip(background_music, -40)
        background_music = audio_loop(background_music, duration=video.duration)
        return video.set_audio(mp.CompositeAudioClip([video.audio, background_music]))

# %%
video_output_file = story_folder / "output.mp4"
video_editor = VideoEditor(script, clip_manager, live_anchor, test_mode, music, Path("./assets/music-1.mp3"), output_resolution=output_resolution, bitrate=bitrate, logo_path=Path("./assets/lower_thirds_logo.png"), font=Path("./assets/Khand-SemiBold.ttf"), error_handler=error_handler)
print("Assembling video")
video_editor.assemble_video(output_file=video_output_file)
# Out:
# Assembling video
# assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/audio/1.mp3
# assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/audio/1.mp3
# assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/audio/5.mp3
# assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/audio/5.mp3
# assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/audio/6.mp3
#
#
#
#
#
#
#
#
#
#
# chunk:  36%|██████████████████████████████████████▎                                                                   | 547/1513 [22:29<00:00, 1053.01it/s, now=None]
# t:   3%|███▋                                                                                                             | 66/2057 [25:37<01:30, 21.95it/s, now=None]
#
#
# t:  11%|███████████▊                                                                                                    | 216/2057 [21:56<01:24, 21.73it/s, now=None]
#
#
#
# t:   1%|█▋                                                                                                               | 59/4098 [03:18<02:52, 23.44it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
# chunk:  36%|██████████████████████████████████████▎                                                                   | 547/1513 [22:29<00:00, 1053.01it/s, now=None]
# t:   3%|███▋                                                                                                             | 66/2057 [25:37<01:30, 21.95it/s, now=None]
#
#
# t:  11%|███████████▊                                                                                                    | 216/2057 [21:56<01:24, 21.73it/s, now=None]
#
#
#
# t:   1%|█▋                                                                                                               | 59/4098 [03:18<02:52, 23.44it/s, now=None]
# Moviepy - Building video assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/output.mp4.
# MoviePy - Writing audio in outputTEMP_MPY_wvf_snd.mp4
# chunk:   0%|                                                                                                                      | 0/3015 [00:00<?, ?it/s, now=None]
#
#
#
#
# chunk:   4%|███▉                                                                                                       | 110/3015 [00:00<00:03, 919.67it/s, now=None]
#
#
#
#
# chunk:   7%|███████▏                                                                                                   | 204/3015 [00:00<00:03, 909.39it/s, now=None]
#
#
#
#
# chunk:  10%|██████████▍                                                                                                | 295/3015 [00:00<00:03, 875.90it/s, now=None]
#
#
#
#
# chunk:  13%|█████████████▉                                                                                             | 392/3015 [00:00<00:02, 900.35it/s, now=None]
#
#
#
#
# chunk:  16%|█████████████████▏                                                                                         | 486/3015 [00:00<00:02, 898.32it/s, now=None]
#
#
#
#
# chunk:  20%|████████████████████▊                                                                                      | 588/3015 [00:00<00:02, 914.98it/s, now=None]
#
#
#
#
# chunk:  23%|█████████████████████████                                                                                  | 706/3015 [00:00<00:02, 991.78it/s, now=None]
#
#
#
#
# chunk:  27%|████████████████████████████▌                                                                              | 806/3015 [00:00<00:02, 969.70it/s, now=None]
#
#
#
#
# chunk:  30%|████████████████████████████████                                                                           | 904/3015 [00:00<00:02, 921.02it/s, now=None]
#
#
#
#
# chunk:  33%|███████████████████████████████████▍                                                                       | 997/3015 [00:01<00:02, 917.97it/s, now=None]
#
#
#
#
# chunk:  36%|██████████████████████████████████████▎                                                                   | 1090/3015 [00:01<00:02, 905.07it/s, now=None]
#
#
#
#
# chunk:  39%|█████████████████████████████████████████▌                                                                | 1183/3015 [00:01<00:02, 911.21it/s, now=None]
#
#
#
#
# chunk:  43%|█████████████████████████████████████████████                                                             | 1282/3015 [00:01<00:04, 373.06it/s, now=None]
#
#
#
#
# chunk:  49%|███████████████████████████████████████████████████▋                                                      | 1469/3015 [00:02<00:02, 586.95it/s, now=None]
#
#
#
#
# chunk:  54%|█████████████████████████████████████████████████████████                                                 | 1623/3015 [00:02<00:01, 747.68it/s, now=None]
#
#
#
#
# chunk:  58%|█████████████████████████████████████████████████████████████▏                                            | 1742/3015 [00:02<00:01, 826.16it/s, now=None]
#
#
#
#
# chunk:  62%|██████████████████████████████████████████████████████████████████                                        | 1879/3015 [00:02<00:01, 936.23it/s, now=None]
#
#
#
#
# chunk:  67%|██████████████████████████████████████████████████████████████████████▍                                  | 2024/3015 [00:02<00:00, 1051.07it/s, now=None]
#
#
#
#
# chunk:  71%|███████████████████████████████████████████████████████████████████████████▋                              | 2152/3015 [00:02<00:00, 990.59it/s, now=None]
#
#
#
#
# chunk:  75%|██████████████████████████████████████████████████████████████████████████████▉                          | 2268/3015 [00:02<00:00, 1018.41it/s, now=None]
#
#
#
#
# chunk:  79%|███████████████████████████████████████████████████████████████████████████████████▋                      | 2382/3015 [00:02<00:00, 993.07it/s, now=None]
#
#
#
#
# chunk:  83%|███████████████████████████████████████████████████████████████████████████████████████▌                  | 2490/3015 [00:02<00:00, 966.69it/s, now=None]
#
#
#
#
# chunk:  86%|███████████████████████████████████████████████████████████████████████████████████████████▏              | 2593/3015 [00:03<00:00, 951.16it/s, now=None]
#
#
#
#
# chunk:  90%|██████████████████████████████████████████████████████████████████████████████████████████████▉           | 2700/3015 [00:03<00:00, 974.16it/s, now=None]
#
#
#
#
# chunk:  93%|██████████████████████████████████████████████████████████████████████████████████████████████████▍       | 2801/3015 [00:03<00:00, 979.31it/s, now=None]
#
#
#
#
# chunk:  96%|██████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 2908/3015 [00:03<00:00, 996.95it/s, now=None]
#
#
#
#
# chunk: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▊| 3010/3015 [00:03<00:00, 955.11it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  36%|██████████████████████████████████████▎                                                                   | 547/1513 [22:32<00:00, 1053.01it/s, now=None]
# t:   3%|███▋                                                                                                             | 66/2057 [25:40<01:30, 21.95it/s, now=None]
#
#
# t:  11%|███████████▊                                                                                                    | 216/2057 [22:00<01:24, 21.73it/s, now=None]
#
#
#
# t:   1%|█▋                                                                                                               | 59/4098 [03:21<02:52, 23.44it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
# chunk:  36%|██████████████████████████████████████▎                                                                   | 547/1513 [22:32<00:00, 1053.01it/s, now=None]
# t:   3%|███▋                                                                                                             | 66/2057 [25:40<01:30, 21.95it/s, now=None]
#
#
# t:  11%|███████████▊                                                                                                    | 216/2057 [22:00<01:24, 21.73it/s, now=None]
#
#
#
# t:   1%|█▋                                                                                                               | 59/4098 [03:21<02:52, 23.44it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video assets/Biden Defiant Amid Democratic Pressure, Vows to Stay in Race as NATO Summit Looms/output.mp4
# t:   0%|                                                                                                                          | 0/4098 [00:00<?, ?it/s, now=None]
#
#
#
#
# t:   0%|                                                                                                                  | 3/4098 [00:00<03:11, 21.33it/s, now=None]
#
#
#
#
# t:   0%|▏                                                                                                                 | 6/4098 [00:00<03:33, 19.19it/s, now=None]
#
#
#
#
# t:   0%|▏                                                                                                                 | 8/4098 [00:00<03:45, 18.15it/s, now=None]
#
#
#
#
# t:   0%|▎                                                                                                                | 10/4098 [00:00<03:44, 18.20it/s, now=None]
#
#
#
#
# t:   0%|▎                                                                                                                | 12/4098 [00:00<03:41, 18.44it/s, now=None]
#
#
#
#
# t:   0%|▍                                                                                                                | 15/4098 [00:00<03:27, 19.68it/s, now=None]
#
#
#
#
# t:   0%|▍                                                                                                                | 18/4098 [00:00<03:18, 20.60it/s, now=None]
#
#
#
#
# t:   1%|▌                                                                                                                | 21/4098 [00:01<03:09, 21.46it/s, now=None]
#
#
#
#
# t:   1%|▋                                                                                                                | 24/4098 [00:01<03:04, 22.05it/s, now=None]
#
#
#
#
# t:   1%|▋                                                                                                                | 27/4098 [00:01<03:00, 22.58it/s, now=None]
#
#
#
#
# t:   1%|▊                                                                                                                | 30/4098 [00:01<02:56, 23.03it/s, now=None]
#
#
#
#
# t:   1%|▉                                                                                                                | 33/4098 [00:01<02:52, 23.54it/s, now=None]
#
#
#
#
# t:   1%|▉                                                                                                                | 36/4098 [00:01<02:58, 22.79it/s, now=None]
#
#
#
#
# t:   1%|█                                                                                                                | 39/4098 [00:01<03:02, 22.29it/s, now=None]
#
#
#
#
# t:   1%|█▏                                                                                                               | 42/4098 [00:01<03:03, 22.07it/s, now=None]
#
#
#
#
# t:   1%|█▏                                                                                                               | 45/4098 [00:02<03:05, 21.81it/s, now=None]
#
#
#
#
# t:   1%|█▎                                                                                                               | 48/4098 [00:02<03:09, 21.38it/s, now=None]
#
#
#
#
# t:   1%|█▍                                                                                                               | 51/4098 [00:02<03:11, 21.09it/s, now=None]
#
#
#
#
# t:   1%|█▍                                                                                                               | 54/4098 [00:02<03:18, 20.35it/s, now=None]
#
#
#
#
# t:   1%|█▌                                                                                                               | 57/4098 [00:02<03:18, 20.40it/s, now=None]
#
#
#
#
# t:   1%|█▋                                                                                                               | 60/4098 [00:02<03:18, 20.38it/s, now=None]
#
#
#
#
# t:   2%|█▋                                                                                                               | 63/4098 [00:02<03:10, 21.14it/s, now=None]
#
#
#
#
# t:   2%|█▊                                                                                                               | 66/4098 [00:03<03:07, 21.46it/s, now=None]
#
#
#
#
# t:   2%|█▉                                                                                                               | 69/4098 [00:03<03:12, 20.91it/s, now=None]
#
#
#
#
# t:   2%|█▉                                                                                                               | 72/4098 [00:03<03:16, 20.49it/s, now=None]
#
#
#
#
# t:   2%|██                                                                                                               | 75/4098 [00:03<03:11, 21.04it/s, now=None]
#
#
#
#
# t:   2%|██▏                                                                                                              | 78/4098 [00:03<03:12, 20.83it/s, now=None]
#
#
#
#
# t:   2%|██▏                                                                                                              | 81/4098 [00:03<03:14, 20.64it/s, now=None]
#
#
#
#
# t:   2%|██▎                                                                                                              | 84/4098 [00:04<03:14, 20.59it/s, now=None]
#
#
#
#
# t:   2%|██▍                                                                                                              | 87/4098 [00:04<03:18, 20.22it/s, now=None]
#
#
#
#
# t:   2%|██▍                                                                                                              | 90/4098 [00:04<03:20, 19.96it/s, now=None]
#
#
#
#
# t:   2%|██▌                                                                                                              | 93/4098 [00:04<03:12, 20.84it/s, now=None]
#
#
#
#
# t:   2%|██▋                                                                                                              | 96/4098 [00:04<03:15, 20.50it/s, now=None]
#
#
#
#
# t:   2%|██▋                                                                                                              | 99/4098 [00:04<03:15, 20.49it/s, now=None]
#
#
#
#
# t:   2%|██▊                                                                                                             | 102/4098 [00:04<03:11, 20.84it/s, now=None]
#
#
#
#
# t:   3%|██▊                                                                                                             | 105/4098 [00:05<03:10, 20.91it/s, now=None]
#
#
#
#
# t:   3%|██▉                                                                                                             | 108/4098 [00:05<03:11, 20.80it/s, now=None]
#
#
#
#
# t:   3%|███                                                                                                             | 111/4098 [00:05<03:19, 19.95it/s, now=None]
#
#
#
#
# t:   3%|███                                                                                                             | 114/4098 [00:05<03:16, 20.24it/s, now=None]
#
#
#
#
# t:   3%|███▏                                                                                                            | 117/4098 [00:05<03:15, 20.35it/s, now=None]
#
#
#
#
# t:   3%|███▎                                                                                                            | 120/4098 [00:05<03:13, 20.54it/s, now=None]
#
#
#
#
# t:   3%|███▎                                                                                                            | 123/4098 [00:05<03:07, 21.23it/s, now=None]
#
#
#
#
# t:   3%|███▍                                                                                                            | 126/4098 [00:06<03:05, 21.38it/s, now=None]
#
#
#
#
# t:   3%|███▌                                                                                                            | 129/4098 [00:06<03:10, 20.84it/s, now=None]
#
#
#
#
# t:   3%|███▌                                                                                                            | 132/4098 [00:06<03:09, 20.88it/s, now=None]
#
#
#
#
# t:   3%|███▋                                                                                                            | 135/4098 [00:06<03:09, 20.90it/s, now=None]
#
#
#
#
# t:   3%|███▊                                                                                                            | 138/4098 [00:06<03:14, 20.31it/s, now=None]
#
#
#
#
# t:   3%|███▊                                                                                                            | 141/4098 [00:06<03:11, 20.71it/s, now=None]
#
#
#
#
# t:   4%|███▉                                                                                                            | 144/4098 [00:06<03:10, 20.78it/s, now=None]
#
#
#
#
# t:   4%|████                                                                                                            | 147/4098 [00:07<03:12, 20.49it/s, now=None]
#
#
#
#
# t:   4%|████                                                                                                            | 150/4098 [00:07<03:11, 20.66it/s, now=None]
#
#
#
#
# t:   4%|████▏                                                                                                           | 153/4098 [00:07<03:11, 20.56it/s, now=None]
#
#
#
#
# t:   4%|████▎                                                                                                           | 156/4098 [00:07<03:12, 20.53it/s, now=None]
#
#
#
#
# t:   4%|████▎                                                                                                           | 159/4098 [00:07<03:14, 20.26it/s, now=None]
#
#
#
#
# t:   4%|████▍                                                                                                           | 162/4098 [00:07<03:15, 20.16it/s, now=None]
#
#
#
#
# t:   4%|████▌                                                                                                           | 165/4098 [00:07<03:16, 20.05it/s, now=None]
#
#
#
#
# t:   4%|████▌                                                                                                           | 168/4098 [00:08<03:16, 20.01it/s, now=None]
#
#
#
#
# t:   4%|████▋                                                                                                           | 171/4098 [00:08<03:15, 20.10it/s, now=None]
#
#
#
#
# t:   4%|████▊                                                                                                           | 174/4098 [00:08<03:12, 20.35it/s, now=None]
#
#
#
#
# t:   4%|████▊                                                                                                           | 177/4098 [00:08<03:09, 20.66it/s, now=None]
#
#
#
#
# t:   4%|████▉                                                                                                           | 180/4098 [00:08<03:12, 20.31it/s, now=None]
#
#
#
#
# t:   4%|█████                                                                                                           | 183/4098 [00:08<03:09, 20.65it/s, now=None]
#
#
#
#
# t:   5%|█████                                                                                                           | 186/4098 [00:08<03:04, 21.22it/s, now=None]
#
#
#
#
# t:   5%|█████▏                                                                                                          | 189/4098 [00:09<03:00, 21.65it/s, now=None]
#
#
#
#
# t:   5%|█████▏                                                                                                          | 192/4098 [00:09<02:57, 22.07it/s, now=None]
#
#
#
#
# t:   5%|█████▎                                                                                                          | 195/4098 [00:09<02:55, 22.29it/s, now=None]
#
#
#
#
# t:   5%|█████▍                                                                                                          | 198/4098 [00:09<03:00, 21.63it/s, now=None]
#
#
#
#
# t:   5%|█████▍                                                                                                          | 201/4098 [00:09<03:04, 21.10it/s, now=None]
#
#
#
#
# t:   5%|█████▌                                                                                                          | 204/4098 [00:09<03:00, 21.53it/s, now=None]
#
#
#
#
# t:   5%|█████▋                                                                                                          | 207/4098 [00:09<02:59, 21.66it/s, now=None]
#
#
#
#
# t:   5%|█████▋                                                                                                          | 210/4098 [00:10<02:57, 21.91it/s, now=None]
#
#
#
#
# t:   5%|█████▊                                                                                                          | 213/4098 [00:10<02:59, 21.61it/s, now=None]
#
#
#
#
# t:   5%|█████▉                                                                                                          | 216/4098 [00:10<03:02, 21.25it/s, now=None]
#
#
#
#
# t:   5%|█████▉                                                                                                          | 219/4098 [00:10<03:03, 21.09it/s, now=None]
#
#
#
#
# t:   5%|██████                                                                                                          | 222/4098 [00:10<03:05, 20.86it/s, now=None]
#
#
#
#
# t:   5%|██████▏                                                                                                         | 225/4098 [00:10<03:05, 20.84it/s, now=None]
#
#
#
#
# t:   6%|██████▏                                                                                                         | 228/4098 [00:10<03:06, 20.75it/s, now=None]
#
#
#
#
# t:   6%|██████▎                                                                                                         | 231/4098 [00:11<03:05, 20.79it/s, now=None]
#
#
#
#
# t:   6%|██████▍                                                                                                         | 234/4098 [00:11<03:07, 20.57it/s, now=None]
#
#
#
#
# t:   6%|██████▍                                                                                                         | 237/4098 [00:11<03:05, 20.81it/s, now=None]
#
#
#
#
# t:   6%|██████▌                                                                                                         | 240/4098 [00:11<03:05, 20.78it/s, now=None]
#
#
#
#
# t:   6%|██████▋                                                                                                         | 243/4098 [00:11<03:06, 20.69it/s, now=None]
#
#
#
#
# t:   6%|██████▋                                                                                                         | 246/4098 [00:11<03:04, 20.83it/s, now=None]
#
#
#
#
# t:   6%|██████▊                                                                                                         | 249/4098 [00:11<03:00, 21.33it/s, now=None]
#
#
#
#
# t:   6%|██████▉                                                                                                         | 252/4098 [00:12<02:56, 21.82it/s, now=None]
#
#
#
#
# t:   6%|██████▉                                                                                                         | 255/4098 [00:12<02:53, 22.13it/s, now=None]
#
#
#
#
# t:   6%|███████                                                                                                         | 258/4098 [00:12<02:51, 22.34it/s, now=None]
#
#
#
#
# t:   6%|███████▏                                                                                                        | 261/4098 [00:12<02:50, 22.55it/s, now=None]
#
#
#
#
# t:   6%|███████▏                                                                                                        | 264/4098 [00:12<02:50, 22.49it/s, now=None]
#
#
#
#
# t:   7%|███████▎                                                                                                        | 267/4098 [00:12<02:53, 22.11it/s, now=None]
#
#
#
#
# t:   7%|███████▍                                                                                                        | 270/4098 [00:12<02:53, 22.05it/s, now=None]
#
#
#
#
# t:   7%|███████▍                                                                                                        | 273/4098 [00:12<02:52, 22.18it/s, now=None]
#
#
#
#
# t:   7%|███████▌                                                                                                        | 276/4098 [00:13<02:53, 22.01it/s, now=None]
#
#
#
#
# t:   7%|███████▋                                                                                                        | 279/4098 [00:13<02:52, 22.14it/s, now=None]
#
#
#
#
# t:   7%|███████▋                                                                                                        | 282/4098 [00:13<02:51, 22.30it/s, now=None]
#
#
#
#
# t:   7%|███████▊                                                                                                        | 285/4098 [00:13<02:48, 22.57it/s, now=None]
#
#
#
#
# t:   7%|███████▊                                                                                                        | 288/4098 [00:13<02:48, 22.56it/s, now=None]
#
#
#
#
# t:   7%|███████▉                                                                                                        | 291/4098 [00:13<02:48, 22.57it/s, now=None]
#
#
#
#
# t:   7%|████████                                                                                                        | 294/4098 [00:13<02:49, 22.43it/s, now=None]
#
#
#
#
# t:   7%|████████                                                                                                        | 297/4098 [00:14<02:48, 22.49it/s, now=None]
#
#
#
#
# t:   7%|████████▏                                                                                                       | 300/4098 [00:14<02:49, 22.38it/s, now=None]
#
#
#
#
# t:   7%|████████▎                                                                                                       | 303/4098 [00:14<02:50, 22.30it/s, now=None]
#
#
#
#
# t:   7%|████████▎                                                                                                       | 306/4098 [00:14<02:50, 22.21it/s, now=None]
#
#
#
#
# t:   8%|████████▍                                                                                                       | 309/4098 [00:14<02:50, 22.18it/s, now=None]
#
#
#
#
# t:   8%|████████▌                                                                                                       | 312/4098 [00:14<02:51, 22.03it/s, now=None]
#
#
#
#
# t:   8%|████████▌                                                                                                       | 315/4098 [00:14<02:51, 22.00it/s, now=None]
#
#
#
#
# t:   8%|████████▋                                                                                                       | 318/4098 [00:15<02:54, 21.63it/s, now=None]
#
#
#
#
# t:   8%|████████▊                                                                                                       | 321/4098 [00:15<02:58, 21.17it/s, now=None]
#
#
#
#
# t:   8%|████████▊                                                                                                       | 324/4098 [00:15<02:55, 21.48it/s, now=None]
#
#
#
#
# t:   8%|████████▉                                                                                                       | 327/4098 [00:15<02:56, 21.36it/s, now=None]
#
#
#
#
# t:   8%|█████████                                                                                                       | 330/4098 [00:15<02:55, 21.52it/s, now=None]
#
#
#
#
# t:   8%|█████████                                                                                                       | 333/4098 [00:15<02:52, 21.77it/s, now=None]
#
#
#
#
# t:   8%|█████████▏                                                                                                      | 336/4098 [00:15<02:52, 21.86it/s, now=None]
#
#
#
#
# t:   8%|█████████▎                                                                                                      | 339/4098 [00:15<02:50, 22.04it/s, now=None]
#
#
#
#
# t:   8%|█████████▎                                                                                                      | 342/4098 [00:16<02:50, 22.09it/s, now=None]
#
#
#
#
# t:   8%|█████████▍                                                                                                      | 345/4098 [00:16<02:48, 22.26it/s, now=None]
#
#
#
#
# t:   8%|█████████▌                                                                                                      | 348/4098 [00:16<02:47, 22.33it/s, now=None]
#
#
#
#
# t:   9%|█████████▌                                                                                                      | 351/4098 [00:16<02:45, 22.60it/s, now=None]
#
#
#
#
# t:   9%|█████████▋                                                                                                      | 354/4098 [00:16<02:43, 22.86it/s, now=None]
#
#
#
#
# t:   9%|█████████▊                                                                                                      | 357/4098 [00:16<02:42, 23.06it/s, now=None]
#
#
#
#
# t:   9%|█████████▊                                                                                                      | 360/4098 [00:16<02:41, 23.14it/s, now=None]
#
#
#
#
# t:   9%|█████████▉                                                                                                      | 363/4098 [00:17<02:42, 23.02it/s, now=None]
#
#
#
#
# t:   9%|██████████                                                                                                      | 366/4098 [00:17<02:40, 23.25it/s, now=None]
#
#
#
#
# t:   9%|██████████                                                                                                      | 369/4098 [00:17<02:39, 23.32it/s, now=None]
#
#
#
#
# t:   9%|██████████▏                                                                                                     | 372/4098 [00:17<02:41, 23.11it/s, now=None]
#
#
#
#
# t:   9%|██████████▏                                                                                                     | 375/4098 [00:17<02:43, 22.75it/s, now=None]
#
#
#
#
# t:   9%|██████████▎                                                                                                     | 378/4098 [00:17<02:46, 22.36it/s, now=None]
#
#
#
#
# t:   9%|██████████▍                                                                                                     | 381/4098 [00:17<02:46, 22.29it/s, now=None]
#
#
#
#
# t:   9%|██████████▍                                                                                                     | 384/4098 [00:17<02:46, 22.26it/s, now=None]
#
#
#
#
# t:   9%|██████████▌                                                                                                     | 387/4098 [00:18<02:47, 22.16it/s, now=None]
#
#
#
#
# t:  10%|██████████▋                                                                                                     | 390/4098 [00:18<02:46, 22.25it/s, now=None]
#
#
#
#
# t:  10%|██████████▋                                                                                                     | 393/4098 [00:18<02:46, 22.30it/s, now=None]
#
#
#
#
# t:  10%|██████████▊                                                                                                     | 396/4098 [00:18<02:46, 22.28it/s, now=None]
#
#
#
#
# t:  10%|██████████▉                                                                                                     | 399/4098 [00:18<02:46, 22.21it/s, now=None]
#
#
#
#
# t:  10%|██████████▉                                                                                                     | 402/4098 [00:18<02:47, 22.06it/s, now=None]
#
#
#
#
# t:  10%|███████████                                                                                                     | 405/4098 [00:18<02:47, 22.10it/s, now=None]
#
#
#
#
# t:  10%|███████████▏                                                                                                    | 408/4098 [00:19<02:46, 22.14it/s, now=None]
#
#
#
#
# t:  10%|███████████▏                                                                                                    | 411/4098 [00:19<02:46, 22.12it/s, now=None]
#
#
#
#
# t:  10%|███████████▎                                                                                                    | 414/4098 [00:19<02:47, 21.94it/s, now=None]
#
#
#
#
# t:  10%|███████████▍                                                                                                    | 417/4098 [00:19<02:54, 21.11it/s, now=None]
#
#
#
#
# t:  10%|███████████▍                                                                                                    | 420/4098 [00:19<02:53, 21.14it/s, now=None]
#
#
#
#
# t:  10%|███████████▌                                                                                                    | 423/4098 [00:19<02:50, 21.50it/s, now=None]
#
#
#
#
# t:  10%|███████████▋                                                                                                    | 426/4098 [00:19<02:50, 21.50it/s, now=None]
#
#
#
#
# t:  10%|███████████▋                                                                                                    | 429/4098 [00:20<02:48, 21.82it/s, now=None]
#
#
#
#
# t:  11%|███████████▊                                                                                                    | 432/4098 [00:20<02:49, 21.61it/s, now=None]
#
#
#
#
# t:  11%|███████████▉                                                                                                    | 435/4098 [00:20<02:52, 21.23it/s, now=None]
#
#
#
#
# t:  11%|███████████▉                                                                                                    | 438/4098 [00:20<02:52, 21.25it/s, now=None]
#
#
#
#
# t:  11%|████████████                                                                                                    | 441/4098 [00:20<02:52, 21.18it/s, now=None]
#
#
#
#
# t:  11%|████████████▏                                                                                                   | 444/4098 [00:20<02:54, 20.99it/s, now=None]
#
#
#
#
# t:  11%|████████████▏                                                                                                   | 447/4098 [00:20<02:57, 20.62it/s, now=None]
#
#
#
#
# t:  11%|████████████▎                                                                                                   | 450/4098 [00:21<02:57, 20.52it/s, now=None]
#
#
#
#
# t:  11%|████████████▍                                                                                                   | 453/4098 [00:21<02:58, 20.37it/s, now=None]
#
#
#
#
# t:  11%|████████████▍                                                                                                   | 456/4098 [00:21<02:59, 20.26it/s, now=None]
#
#
#
#
# t:  11%|████████████▌                                                                                                   | 459/4098 [00:21<02:58, 20.34it/s, now=None]
#
#
#
#
# t:  11%|████████████▋                                                                                                   | 462/4098 [00:21<02:58, 20.38it/s, now=None]
#
#
#
#
# t:  11%|████████████▋                                                                                                   | 465/4098 [00:21<02:57, 20.50it/s, now=None]
#
#
#
#
# t:  11%|████████████▊                                                                                                   | 468/4098 [00:21<02:56, 20.60it/s, now=None]
#
#
#
#
# t:  11%|████████████▊                                                                                                   | 471/4098 [00:22<02:52, 21.01it/s, now=None]
#
#
#
#
# t:  12%|████████████▉                                                                                                   | 474/4098 [00:22<02:50, 21.19it/s, now=None]
#
#
#
#
# t:  12%|█████████████                                                                                                   | 477/4098 [00:22<02:50, 21.19it/s, now=None]
#
#
#
#
# t:  12%|█████████████                                                                                                   | 480/4098 [00:22<02:52, 20.95it/s, now=None]
#
#
#
#
# t:  12%|█████████████▏                                                                                                  | 483/4098 [00:22<02:53, 20.81it/s, now=None]
#
#
#
#
# t:  12%|█████████████▎                                                                                                  | 486/4098 [00:22<02:54, 20.73it/s, now=None]
#
#
#
#
# t:  12%|█████████████▎                                                                                                  | 489/4098 [00:22<02:55, 20.61it/s, now=None]
#
#
#
#
# t:  12%|█████████████▍                                                                                                  | 492/4098 [00:23<02:57, 20.27it/s, now=None]
#
#
#
#
# t:  12%|█████████████▌                                                                                                  | 495/4098 [00:23<02:51, 21.06it/s, now=None]
#
#
#
#
# t:  12%|█████████████▌                                                                                                  | 498/4098 [00:23<02:47, 21.52it/s, now=None]
#
#
#
#
# t:  12%|█████████████▋                                                                                                  | 501/4098 [00:23<02:44, 21.87it/s, now=None]
#
#
#
#
# t:  12%|█████████████▊                                                                                                  | 504/4098 [00:23<02:43, 21.97it/s, now=None]
#
#
#
#
# t:  12%|█████████████▊                                                                                                  | 507/4098 [00:23<02:44, 21.83it/s, now=None]
#
#
#
#
# t:  12%|█████████████▉                                                                                                  | 510/4098 [00:23<02:46, 21.55it/s, now=None]
#
#
#
#
# t:  13%|██████████████                                                                                                  | 513/4098 [00:24<02:45, 21.61it/s, now=None]
#
#
#
#
# t:  13%|██████████████                                                                                                  | 516/4098 [00:24<02:46, 21.55it/s, now=None]
#
#
#
#
# t:  13%|██████████████▏                                                                                                 | 519/4098 [00:24<02:47, 21.38it/s, now=None]
#
#
#
#
# t:  13%|██████████████▎                                                                                                 | 522/4098 [00:24<02:47, 21.39it/s, now=None]
#
#
#
#
# t:  13%|██████████████▎                                                                                                 | 525/4098 [00:24<02:43, 21.90it/s, now=None]
#
#
#
#
# t:  13%|██████████████▍                                                                                                 | 528/4098 [00:24<02:42, 21.93it/s, now=None]
#
#
#
#
# t:  13%|██████████████▌                                                                                                 | 531/4098 [00:24<02:44, 21.63it/s, now=None]
#
#
#
#
# t:  13%|██████████████▌                                                                                                 | 534/4098 [00:25<02:47, 21.23it/s, now=None]
#
#
#
#
# t:  13%|██████████████▋                                                                                                 | 537/4098 [00:25<02:50, 20.88it/s, now=None]
#
#
#
#
# t:  13%|██████████████▊                                                                                                 | 540/4098 [00:25<02:48, 21.13it/s, now=None]
#
#
#
#
# t:  13%|██████████████▊                                                                                                 | 543/4098 [00:25<02:48, 21.15it/s, now=None]
#
#
#
#
# t:  13%|██████████████▉                                                                                                 | 546/4098 [00:25<02:46, 21.28it/s, now=None]
#
#
#
#
# t:  13%|███████████████                                                                                                 | 549/4098 [00:25<02:44, 21.60it/s, now=None]
#
#
#
#
# t:  13%|███████████████                                                                                                 | 552/4098 [00:25<02:40, 22.08it/s, now=None]
#
#
#
#
# t:  14%|███████████████▏                                                                                                | 555/4098 [00:25<02:38, 22.33it/s, now=None]
#
#
#
#
# t:  14%|███████████████▎                                                                                                | 558/4098 [00:26<02:40, 22.09it/s, now=None]
#
#
#
#
# t:  14%|███████████████▎                                                                                                | 561/4098 [00:26<02:38, 22.35it/s, now=None]
#
#
#
#
# t:  14%|███████████████▍                                                                                                | 564/4098 [00:26<02:35, 22.68it/s, now=None]
#
#
#
#
# t:  14%|███████████████▍                                                                                                | 567/4098 [00:26<02:39, 22.09it/s, now=None]
#
#
#
#
# t:  14%|███████████████▌                                                                                                | 570/4098 [00:26<02:38, 22.31it/s, now=None]
#
#
#
#
# t:  14%|███████████████▋                                                                                                | 573/4098 [00:26<02:36, 22.49it/s, now=None]
#
#
#
#
# t:  14%|███████████████▋                                                                                                | 576/4098 [00:26<02:34, 22.80it/s, now=None]
#
#
#
#
# t:  14%|███████████████▊                                                                                                | 579/4098 [00:27<02:36, 22.47it/s, now=None]
#
#
#
#
# t:  14%|███████████████▉                                                                                                | 582/4098 [00:27<02:36, 22.49it/s, now=None]
#
#
#
#
# t:  14%|███████████████▉                                                                                                | 585/4098 [00:27<02:38, 22.13it/s, now=None]
#
#
#
#
# t:  14%|████████████████                                                                                                | 588/4098 [00:27<02:37, 22.27it/s, now=None]
#
#
#
#
# t:  14%|████████████████▏                                                                                               | 591/4098 [00:27<02:36, 22.48it/s, now=None]
#
#
#
#
# t:  14%|████████████████▏                                                                                               | 594/4098 [00:27<02:34, 22.75it/s, now=None]
#
#
#
#
# t:  15%|████████████████▎                                                                                               | 597/4098 [00:27<02:32, 22.91it/s, now=None]
#
#
#
#
# t:  15%|████████████████▍                                                                                               | 600/4098 [00:27<02:32, 22.94it/s, now=None]
#
#
#
#
# t:  15%|████████████████▍                                                                                               | 603/4098 [00:28<02:34, 22.62it/s, now=None]
#
#
#
#
# t:  15%|████████████████▌                                                                                               | 606/4098 [00:28<02:35, 22.48it/s, now=None]
#
#
#
#
# t:  15%|████████████████▋                                                                                               | 609/4098 [00:28<02:37, 22.10it/s, now=None]
#
#
#
#
# t:  15%|████████████████▋                                                                                               | 612/4098 [00:28<02:38, 22.02it/s, now=None]
#
#
#
#
# t:  15%|████████████████▊                                                                                               | 615/4098 [00:28<02:39, 21.83it/s, now=None]
#
#
#
#
# t:  15%|████████████████▉                                                                                               | 618/4098 [00:28<02:42, 21.43it/s, now=None]
#
#
#
#
# t:  15%|████████████████▉                                                                                               | 621/4098 [00:28<02:39, 21.80it/s, now=None]
#
#
#
#
# t:  15%|█████████████████                                                                                               | 624/4098 [00:29<02:37, 22.06it/s, now=None]
#
#
#
#
# t:  15%|█████████████████▏                                                                                              | 627/4098 [00:29<02:36, 22.14it/s, now=None]
#
#
#
#
# t:  15%|█████████████████▏                                                                                              | 630/4098 [00:29<02:35, 22.26it/s, now=None]
#
#
#
#
# t:  15%|█████████████████▎                                                                                              | 633/4098 [00:29<02:37, 22.06it/s, now=None]
#
#
#
#
# t:  16%|█████████████████▍                                                                                              | 636/4098 [00:29<02:39, 21.66it/s, now=None]
#
#
#
#
# t:  16%|█████████████████▍                                                                                              | 639/4098 [00:29<02:41, 21.40it/s, now=None]
#
#
#
#
# t:  16%|█████████████████▌                                                                                              | 642/4098 [00:29<02:41, 21.37it/s, now=None]
#
#
#
#
# t:  16%|█████████████████▋                                                                                              | 645/4098 [00:30<02:42, 21.29it/s, now=None]
#
#
#
#
# ...
#
#
#
#
# t:  82%|██████████████████████████████████████████████████████████████████████████████████████████▊                    | 3353/4098 [02:48<00:36, 20.35it/s, now=None]
#
#
#
#
# t:  82%|██████████████████████████████████████████████████████████████████████████████████████████▉                    | 3356/4098 [02:48<00:36, 20.16it/s, now=None]
#
#
#
#
# t:  82%|██████████████████████████████████████████████████████████████████████████████████████████▉                    | 3359/4098 [02:48<00:36, 20.26it/s, now=None]
#
#
#
#
# t:  82%|███████████████████████████████████████████████████████████████████████████████████████████                    | 3362/4098 [02:48<00:36, 20.18it/s, now=None]
#
#
#
#
# t:  82%|███████████████████████████████████████████████████████████████████████████████████████████▏                   | 3365/4098 [02:49<00:36, 20.30it/s, now=None]
#
#
#
#
# t:  82%|███████████████████████████████████████████████████████████████████████████████████████████▏                   | 3368/4098 [02:49<00:35, 20.45it/s, now=None]
#
#
#
#
# t:  82%|███████████████████████████████████████████████████████████████████████████████████████████▎                   | 3371/4098 [02:49<00:35, 20.33it/s, now=None]
#
#
#
#
# t:  82%|███████████████████████████████████████████████████████████████████████████████████████████▍                   | 3374/4098 [02:49<00:35, 20.56it/s, now=None]
#
#
#
#
# t:  82%|███████████████████████████████████████████████████████████████████████████████████████████▍                   | 3377/4098 [02:49<00:34, 20.80it/s, now=None]
#
#
#
#
# t:  82%|███████████████████████████████████████████████████████████████████████████████████████████▌                   | 3380/4098 [02:49<00:34, 20.71it/s, now=None]
#
#
#
#
# t:  83%|███████████████████████████████████████████████████████████████████████████████████████████▋                   | 3383/4098 [02:49<00:34, 20.49it/s, now=None]
#
#
#
#
# t:  83%|███████████████████████████████████████████████████████████████████████████████████████████▋                   | 3386/4098 [02:50<00:34, 20.61it/s, now=None]
#
#
#
#
# t:  83%|███████████████████████████████████████████████████████████████████████████████████████████▊                   | 3389/4098 [02:50<00:34, 20.76it/s, now=None]
#
#
#
#
# t:  83%|███████████████████████████████████████████████████████████████████████████████████████████▉                   | 3392/4098 [02:50<00:33, 20.79it/s, now=None]
#
#
#
#
# t:  83%|███████████████████████████████████████████████████████████████████████████████████████████▉                   | 3395/4098 [02:50<00:34, 20.60it/s, now=None]
#
#
#
#
# t:  83%|████████████████████████████████████████████████████████████████████████████████████████████                   | 3398/4098 [02:50<00:34, 20.52it/s, now=None]
#
#
#
#
# t:  83%|████████████████████████████████████████████████████████████████████████████████████████████                   | 3401/4098 [02:50<00:33, 20.81it/s, now=None]
#
#
#
#
# t:  83%|████████████████████████████████████████████████████████████████████████████████████████████▏                  | 3404/4098 [02:50<00:33, 20.93it/s, now=None]
#
#
#
#
# t:  83%|████████████████████████████████████████████████████████████████████████████████████████████▎                  | 3407/4098 [02:51<00:33, 20.71it/s, now=None]
#
#
#
#
# t:  83%|████████████████████████████████████████████████████████████████████████████████████████████▎                  | 3410/4098 [02:51<00:33, 20.78it/s, now=None]
#
#
#
#
# t:  83%|████████████████████████████████████████████████████████████████████████████████████████████▍                  | 3413/4098 [02:51<00:32, 20.91it/s, now=None]
#
#
#
#
# t:  83%|████████████████████████████████████████████████████████████████████████████████████████████▌                  | 3416/4098 [02:51<00:32, 21.00it/s, now=None]
#
#
#
#
# t:  83%|████████████████████████████████████████████████████████████████████████████████████████████▌                  | 3419/4098 [02:51<00:32, 20.79it/s, now=None]
#
#
#
#
# t:  84%|████████████████████████████████████████████████████████████████████████████████████████████▋                  | 3422/4098 [02:51<00:32, 20.70it/s, now=None]
#
#
#
#
# t:  84%|████████████████████████████████████████████████████████████████████████████████████████████▊                  | 3425/4098 [02:51<00:32, 20.68it/s, now=None]
#
#
#
#
# t:  84%|████████████████████████████████████████████████████████████████████████████████████████████▊                  | 3428/4098 [02:52<00:32, 20.62it/s, now=None]
#
#
#
#
# t:  84%|████████████████████████████████████████████████████████████████████████████████████████████▉                  | 3431/4098 [02:52<00:32, 20.38it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████                  | 3434/4098 [02:52<00:32, 20.58it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████                  | 3437/4098 [02:52<00:32, 20.55it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████▏                 | 3440/4098 [02:52<00:31, 20.76it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████▎                 | 3443/4098 [02:52<00:31, 20.48it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████▎                 | 3446/4098 [02:52<00:31, 20.75it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████▍                 | 3449/4098 [02:53<00:31, 20.80it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████▌                 | 3452/4098 [02:53<00:30, 21.03it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████▌                 | 3455/4098 [02:53<00:30, 21.06it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████▋                 | 3458/4098 [02:53<00:30, 20.91it/s, now=None]
#
#
#
#
# t:  84%|█████████████████████████████████████████████████████████████████████████████████████████████▋                 | 3461/4098 [02:53<00:30, 20.69it/s, now=None]
#
#
#
#
# t:  85%|█████████████████████████████████████████████████████████████████████████████████████████████▊                 | 3464/4098 [02:53<00:30, 20.75it/s, now=None]
#
#
#
#
# t:  85%|█████████████████████████████████████████████████████████████████████████████████████████████▉                 | 3467/4098 [02:53<00:30, 20.89it/s, now=None]
#
#
#
#
# t:  85%|█████████████████████████████████████████████████████████████████████████████████████████████▉                 | 3470/4098 [02:54<00:30, 20.89it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████                 | 3473/4098 [02:54<00:29, 20.91it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▏                | 3476/4098 [02:54<00:29, 20.87it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▏                | 3479/4098 [02:54<00:29, 20.98it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▎                | 3482/4098 [02:54<00:29, 20.77it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▍                | 3485/4098 [02:54<00:29, 20.62it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▍                | 3488/4098 [02:54<00:29, 20.72it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▌                | 3491/4098 [02:55<00:29, 20.79it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▋                | 3494/4098 [02:55<00:28, 20.83it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▋                | 3497/4098 [02:55<00:28, 20.88it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▊                | 3500/4098 [02:55<00:28, 21.00it/s, now=None]
#
#
#
#
# t:  85%|██████████████████████████████████████████████████████████████████████████████████████████████▉                | 3503/4098 [02:55<00:28, 20.69it/s, now=None]
#
#
#
#
# t:  86%|██████████████████████████████████████████████████████████████████████████████████████████████▉                | 3506/4098 [02:55<00:28, 20.59it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████                | 3509/4098 [02:55<00:28, 20.71it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▏               | 3512/4098 [02:56<00:27, 21.10it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▏               | 3515/4098 [02:56<00:27, 21.34it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▎               | 3518/4098 [02:56<00:27, 21.33it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▎               | 3521/4098 [02:56<00:27, 21.26it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▍               | 3524/4098 [02:56<00:26, 21.36it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▌               | 3527/4098 [02:56<00:26, 21.33it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▌               | 3530/4098 [02:56<00:27, 20.98it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▋               | 3533/4098 [02:57<00:27, 20.89it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▊               | 3536/4098 [02:57<00:26, 20.85it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▊               | 3539/4098 [02:57<00:26, 21.04it/s, now=None]
#
#
#
#
# t:  86%|███████████████████████████████████████████████████████████████████████████████████████████████▉               | 3542/4098 [02:57<00:26, 21.09it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████               | 3545/4098 [02:57<00:26, 20.76it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████               | 3548/4098 [02:57<00:26, 20.74it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▏              | 3551/4098 [02:57<00:26, 20.69it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▎              | 3554/4098 [02:58<00:26, 20.76it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▎              | 3557/4098 [02:58<00:26, 20.63it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▍              | 3560/4098 [02:58<00:26, 20.34it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▌              | 3563/4098 [02:58<00:26, 20.55it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▌              | 3566/4098 [02:58<00:25, 20.55it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▋              | 3569/4098 [02:58<00:25, 20.44it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▊              | 3572/4098 [02:58<00:25, 20.45it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▊              | 3575/4098 [02:59<00:26, 19.99it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▉              | 3578/4098 [02:59<00:25, 20.11it/s, now=None]
#
#
#
#
# t:  87%|████████████████████████████████████████████████████████████████████████████████████████████████▉              | 3581/4098 [02:59<00:25, 20.03it/s, now=None]
#
#
#
#
# t:  87%|█████████████████████████████████████████████████████████████████████████████████████████████████              | 3584/4098 [02:59<00:25, 20.03it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▏             | 3587/4098 [02:59<00:25, 20.41it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▏             | 3590/4098 [02:59<00:25, 20.28it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▎             | 3593/4098 [03:00<00:24, 20.22it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▍             | 3596/4098 [03:00<00:24, 20.34it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▍             | 3599/4098 [03:00<00:24, 20.60it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▌             | 3602/4098 [03:00<00:23, 20.67it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▋             | 3605/4098 [03:00<00:24, 20.44it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▋             | 3608/4098 [03:00<00:24, 20.36it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▊             | 3611/4098 [03:00<00:23, 20.36it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▉             | 3614/4098 [03:01<00:23, 20.30it/s, now=None]
#
#
#
#
# t:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████▉             | 3617/4098 [03:01<00:23, 20.40it/s, now=None]
#
#
#
#
# t:  88%|██████████████████████████████████████████████████████████████████████████████████████████████████             | 3620/4098 [03:01<00:23, 20.27it/s, now=None]
#
#
#
#
# t:  88%|██████████████████████████████████████████████████████████████████████████████████████████████████▏            | 3623/4098 [03:01<00:23, 20.10it/s, now=None]
#
#
#
#
# t:  88%|██████████████████████████████████████████████████████████████████████████████████████████████████▏            | 3626/4098 [03:01<00:23, 20.09it/s, now=None]
#
#
#
#
# t:  89%|██████████████████████████████████████████████████████████████████████████████████████████████████▎            | 3629/4098 [03:01<00:23, 20.03it/s, now=None]
#
#
#
#
# t:  89%|██████████████████████████████████████████████████████████████████████████████████████████████████▍            | 3632/4098 [03:01<00:23, 20.20it/s, now=None]

# %%
gcs = GCSManager()
print("Uploading to GCS")
gcs.upload_to_gcs_url(video_output_file, filename=script.headline, bucket_name="c1-videos")
